# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinmichalsmolen/zum_nlp/blob/main/Wst%C4%99pDoNLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wprowadzenie do Uczenia Maszynowego
#
# ## Wstęp do Przetwarzania Języka Naturalnego
#
# Na tym ćwiczeniu omawiane są podstawy NLP na przykładzie kilku prostych narzędzi i metod modelowania.
#
# Na początku omówimy podstawowe metody analizy tekstu. Do tego zadania użyjemy biblioteki [spacy](https://spacy.io/). Nie jest ona jedynym narzędziem do tego celu, ale jest uznana za jedną z bardziej wydajnych. Inne przykłady to [NLTK](https://www.nltk.org/) (starsza i uważana za mniej nowoczesną) albo [AllenNLP](https://allenai.org/allennlp).
#
#
# Najpierw zainstalujemy bardziej aktualną wersję spacy niż ta, która jest standardowo dostępna w Google Colab:

# %%
# !pip install -U spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.0.17)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.7.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.1.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)

# %% [markdown]
# Potem zainstalujemy model o nazwie `pl_core_news_lg` poleceniem z dokumentacji. Lista modeli jest dostępna [tutaj](https://spacy.io/usage/models):

# %%
# !python -m spacy download pl_core_news_lg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pl-core-news-lg==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pl_core_news_lg-3.3.0/pl_core_news_lg-3.3.0-py3-none-any.whl (573.6 MB)
#      |████████████████████████████████| 573.6 MB 5.4 kB/s
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /usr/local/lib/python3.7/dist-packages (from pl-core-news-lg==3.3.0) (3.3.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (21.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (0.7.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (0.9.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (4.64.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (2.0.7)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (0.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (2.11.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (1.0.2)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (4.1.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (1.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (3.0.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (57.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (1.21.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (1.8.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (0.4.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (2.4.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (8.0.17)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (2.23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->pl-core-news-lg==3.3.0) (2.0.1)
# Installing collected packages: pl-core-news-lg
# Successfully installed pl-core-news-lg-3.3.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pl_core_news_lg')

# %% [markdown]
# Teraz można zaimportować bibliotekę `spacy` i użyć metodę `load` żeby wczytać wyżej zainstalowany model. Metoda ta zwraca objekt który będziemy używać do analizy tekstu:

# %%
import spacy
nlp = spacy.load('pl_core_news_lg')

# %% [markdown]
# Tu wkleiłem kawałek transkrypcji z posiedzenia sejmowego ze stycznia 2022:

# %%
text_sample='Szanowny Panie Marszałku! Wysoka Izbo! Ustawa zapowiadana jako naprawa, chciałoby się rzec, głęboka korekta Nowego Ładu podatkowego poza rekompensatą strat, jeśli chodzi o zakłady pracy chronionej i zakłady aktywności zawodowej, to w gruncie rzeczy jakaś farsa. Tak naprawdę to jest zalegalizowanie rozporządzenia ministra finansów z 7 stycznia 2022 r., rozporządzenia wydanego z przekroczeniem delegacji ustawowych i naruszeniem konstytucji. Próbujecie uporządkować kawałek, ułameczek problemów, które w tym bublu prawnym, jakim jest Nowy Ład, wygenerowaliście. Po tygodniu obowiązywania ustawy okazało się, że ci, którzy mieli zyskiwać, tracą już dzisiaj, ich wypłaty są niższe, a miały być przecież wyższe. Do tego nikt nie wie, jaki zapłaci podatek. To już norma, jeśli chodzi o wasze działania - mniej znaczy więcej, jak u Orwella. To, co proponujecie, to jest zwykłe mydlenie oczu. W sprawie zaliczek: technicznie rzecz ujmując, płatnik będzie obliczał wysokość zaliczki według zasad z 2022 r., następnie według zasad z 2021 r. Jeśli będzie różnica taka, że zaliczka według zasad z 2022 r. będzie wyższa niż ta z 2021 r., to nie będzie pobierać tej różnicy, a definitywne rozliczenie nastąpi dopiero w zeznaniu rocznym. Taki mechanizm jest sposobem odroczenia płatności wyższej niż w 2021 r. zaliczki na podatek, ale nie jest zwolnieniem podatnika z obowiązku stosowania przepisów z 2022 r. W praktyce dla niektórych podatników może to oznaczać konieczność dopłaty podatku w grudniu 2022 r. albo w rozliczeniu rocznym. Podkreślam, te zmiany nie prowadzą do obniżenia podatków, a jedynie są modyfikacją obowiązków płatników i pracodawców, zleceniodawców i organów rentowych w zakresie poboru zaliczki na podatek dochodowy od osób fizycznych. To jest kolejne obciążenie administracyjne dla płatników, czyli polskich przedsiębiorców i ich księgowych. Projekt jest napisany na kolanie - mówiłem to w ramach pierwszego czytania - i to już jest jakaś tradycja. Czas wreszcie przejść z deklaracji do czynów. Ciągle, tak jak prezydent, mówicie, że się uczycie. A nie sztuka się uczyć, trzeba się nauczyć i wyciągać lekcje i wnioski z dotychczasowych działań. Biuro Legislacyjne po raz kolejny złożyło zastrzeżenie, że nie było w stanie przeanalizować zapisów ustawy, w praktyce - że nie ma pewności co do poprawności jej zapisów. Mało tego, w ustawie są zapisy, które są nie do zaakceptowania i nie do przyjęcia. To jest opinia Biura Legislacyjnego Sejmu. Ale wy oczywiście wszystko możecie przegłosować, dowiedliście tego wczoraj na posiedzeniu komisji. To, że narażacie podatników i płatników na nieprzewidywalne dziś konsekwencje, nie ma dla was w gruncie rzeczy znaczenia. Musi być tak, jak chcecie, i tyle. Wczoraj na posiedzeniu komisji finansów dowiedliście, że nie rozumiecie rzeczywistych skutków Nowego Ładu. Nie dociera do was np. to, że tak naprawdę zlikwidowaliście kwotę wolną. Ona była niska do tej pory, ale była. A dzisiaj kwota wolna wynosi zero, bo dochody do 30 tys. zł są opodatkowane stawką 9%, dochody między 30 a 120 tys. zł - stawką 26%, a dochody ponad 120 tys. zł - stawką 41%. Nie zapominajcie, że podatnicy jeszcze muszą zapłacić ZUS - 19,52%. Jakiś łoś was opętał, takie mam wrażenie. Nie dociera do was, że w Polsce przestało się już, praktycznie rzecz biorąc, opłacać pracować. Do tego te rozwiązania prowadzą. Nie ma rozwiązań, które zapowiadaliście, jeśli chodzi o korektę Nowego Ładu. Nie ma w dalszym ciągu ulgi dla klasy średniej, dla zleceniobiorców, dla świadczeń emerytalnych, rentowych. Nie ma żadnej propozycji co do rozliczania rodziców samotnie wychowujących dzieci, a taką deklarację też słyszeliśmy. Nie ma rekompensaty dla organizacji pozarządowych. Nie ma propozycji, o której mówił też premier: złotówka za złotówkę. I nie odnosicie się w ogóle do konsekwencji Nowego Ładu (Dzwonek) w działalności gospodarczej, a one są tu dramatyczne, dramatyczne. Czas albo dokonać głębokiej korekty, a najlepiej posłuchać tego, co mówiliśmy od samego początku i tę część dotyczącą przedsiębiorców po prostu zawiesić. Dziękuję bardzo. '

# %% [markdown]
# ## Składnia tekstu
#
# Teraz można użyć objektu wyżej żeby zanalizować tekst podając go jako arguemnt wywołania objektu zwróconego przez metodę `load` wyżej:

# %%
sejm = nlp(text_sample)

# %%
for i in range(len(sejm)):
  print(sejm[i])
# Out:
# Szanowny
# Panie
# Marszałku
# !
# Wysoka
# Izbo
# !
# Ustawa
# zapowiadana
# jako
# naprawa
# ,
# chciałoby
# się
# rzec
# ,
# głęboka
# korekta
# Nowego
# Ładu
# podatkowego
# poza
# rekompensatą
# strat
# ,
# jeśli
# chodzi
# o
# zakłady
# pracy
# chronionej
# i
# zakłady
# aktywności
# zawodowej
# ,
# to
# w
# gruncie
# rzeczy
# jakaś
# farsa
# .
# Tak
# naprawdę
# to
# jest
# zalegalizowanie
# rozporządzenia
# ministra
# finansów
# z
# 7
# stycznia
# 2022
# r
# .
# ,
# rozporządzenia
# wydanego
# z
# przekroczeniem
# delegacji
# ustawowych
# i
# naruszeniem
# konstytucji
# .
# Próbujecie
# uporządkować
# kawałek
# ,
# ułameczek
# problemów
# ,
# które
# w
# tym
# bublu
# prawnym
# ,
# jakim
# jest
# Nowy
# Ład
# ,
# wygenerowaliście
# .
# Po
# tygodniu
# obowiązywania
# ustawy
# okazało
# się
# ,
# że
# ci
# ,
# którzy
# mieli
# zyskiwać
# ,
# tracą
# już
# dzisiaj
# ,
# ich
# wypłaty
# są
# niższe
# ,
# a
# miały
# być
# przecież
# wyższe
# .
# Do
# tego
# nikt
# nie
# wie
# ,
# jaki
# zapłaci
# podatek
# .
# To
# już
# norma
# ,
# jeśli
# chodzi
# o
# wasze
# działania
# -
# mniej
# znaczy
# więcej
# ,
# jak
# u
# Orwella
# .
# To
# ,
# co
# proponujecie
# ,
# to
# jest
# zwykłe
# mydlenie
# oczu
# .
# W
# sprawie
# zaliczek
# :
# technicznie
# rzecz
# ujmując
# ,
# płatnik
# będzie
# obliczał
# wysokość
# zaliczki
# według
# zasad
# z
# 2022
# r
# .
# ,
# następnie
# według
# zasad
# z
# 2021
# r
# .
# Jeśli
# będzie
# różnica
# taka
# ,
# że
# zaliczka
# według
# zasad
# z
# 2022
# r
# .
# będzie
# wyższa
# niż
# ta
# z
# 2021
# r
# .
# ,
# to
# nie
# będzie
# pobierać
# tej
# różnicy
# ,
# a
# definitywne
# rozliczenie
# nastąpi
# dopiero
# w
# zeznaniu
# rocznym
# .
# Taki
# mechanizm
# jest
# sposobem
# odroczenia
# płatności
# wyższej
# niż
# w
# 2021
# r
# .
# zaliczki
# na
# podatek
# ,
# ale
# nie
# jest
# zwolnieniem
# podatnika
# z
# obowiązku
# stosowania
# przepisów
# z
# 2022
# r
# .
# W
# praktyce
# dla
# niektórych
# podatników
# może
# to
# oznaczać
# konieczność
# dopłaty
# podatku
# w
# grudniu
# 2022
# r
# .
# albo
# w
# rozliczeniu
# rocznym
# .
# Podkreślam
# ,
# te
# zmiany
# nie
# prowadzą
# do
# obniżenia
# podatków
# ,
# a
# jedynie
# są
# modyfikacją
# obowiązków
# płatników
# i
# pracodawców
# ,
# zleceniodawców
# i
# organów
# rentowych
# w
# zakresie
# poboru
# zaliczki
# na
# podatek
# dochodowy
# od
# osób
# fizycznych
# .
# To
# jest
# kolejne
# obciążenie
# administracyjne
# dla
# płatników
# ,
# czyli
# polskich
# przedsiębiorców
# i
# ich
# księgowych
# .
# Projekt
# jest
# napisany
# na
# kolanie
# -
# mówiłem
# to
# w
# ramach
# pierwszego
# czytania
# -
# i
# to
# już
# jest
# jakaś
# tradycja
# .
# Czas
# wreszcie
# przejść
# z
# deklaracji
# do
# czynów
# .
# Ciągle
# ,
# tak
# jak
# prezydent
# ,
# mówicie
# ,
# że
# się
# uczycie
# .
# A
# nie
# sztuka
# się
# uczyć
# ,
# trzeba
# się
# nauczyć
# i
# wyciągać
# lekcje
# i
# wnioski
# z
# dotychczasowych
# działań
# .
# Biuro
# Legislacyjne
# po
# raz
# kolejny
# złożyło
# zastrzeżenie
# ,
# że
# nie
# było
# w
# stanie
# przeanalizować
# zapisów
# ustawy
# ,
# w
# praktyce
# -
# że
# nie
# ma
# pewności
# co
# do
# poprawności
# jej
# zapisów
# .
# Mało
# tego
# ,
# w
# ustawie
# są
# zapisy
# ,
# które
# są
# nie
# do
# zaakceptowania
# i
# nie
# do
# przyjęcia
# .
# To
# jest
# opinia
# Biura
# Legislacyjnego
# Sejmu
# .
# Ale
# wy
# oczywiście
# wszystko
# możecie
# przegłosować
# ,
# dowiedliście
# tego
# wczoraj
# na
# posiedzeniu
# komisji
# .
# To
# ,
# że
# narażacie
# podatników
# i
# płatników
# na
# nieprzewidywalne
# dziś
# konsekwencje
# ,
# nie
# ma
# dla
# was
# w
# gruncie
# rzeczy
# znaczenia
# .
# Musi
# być
# tak
# ,
# jak
# chcecie
# ,
# i
# tyle
# .
# Wczoraj
# na
# posiedzeniu
# komisji
# finansów
# dowiedliście
# ,
# że
# nie
# rozumiecie
# rzeczywistych
# skutków
# Nowego
# Ładu
# .
# Nie
# dociera
# do
# was
# np
# .
# to
# ,
# że
# tak
# naprawdę
# zlikwidowaliście
# kwotę
# wolną
# .
# Ona
# była
# niska
# do
# tej
# pory
# ,
# ale
# była
# .
# A
# dzisiaj
# kwota
# wolna
# wynosi
# zero
# ,
# bo
# dochody
# do
# 30
# tys
# .
# zł
# są
# opodatkowane
# stawką
# 9
# %
# ,
# dochody
# między
# 30
# a
# 120
# tys
# .
# zł
# -
# stawką
# 26
# %
# ,
# a
# dochody
# ponad
# 120
# tys
# .
# zł
# -
# stawką
# 41
# %
# .
# Nie
# zapominajcie
# ,
# że
# podatnicy
# jeszcze
# muszą
# zapłacić
# ZUS
# -
# 19,52
# %
# .
# Jakiś
# łoś
# was
# opętał
# ,
# takie
# mam
# wrażenie
# .
# Nie
# dociera
# do
# was
# ,
# że
# w
# Polsce
# przestało
# się
# już
# ,
# praktycznie
# rzecz
# biorąc
# ,
# opłacać
# pracować
# .
# Do
# tego
# te
# rozwiązania
# prowadzą
# .
# Nie
# ma
# rozwiązań
# ,
# które
# zapowiadaliście
# ,
# jeśli
# chodzi
# o
# korektę
# Nowego
# Ładu
# .
# Nie
# ma
# w
# dalszym
# ciągu
# ulgi
# dla
# klasy
# średniej
# ,
# dla
# zleceniobiorców
# ,
# dla
# świadczeń
# emerytalnych
# ,
# rentowych
# .
# Nie
# ma
# żadnej
# propozycji
# co
# do
# rozliczania
# rodziców
# samotnie
# wychowujących
# dzieci
# ,
# a
# taką
# deklarację
# też
# słyszeliśmy
# .
# Nie
# ma
# rekompensaty
# dla
# organizacji
# pozarządowych
# .
# Nie
# ma
# propozycji
# ,
# o
# której
# mówił
# też
# premier
# :
# złotówka
# za
# złotówkę
# .
# I
# nie
# odnosicie
# się
# w
# ogóle
# do
# konsekwencji
# Nowego
# Ładu
# (
# Dzwonek
# )
# w
# działalności
# gospodarczej
# ,
# a
# one
# są
# tu
# dramatyczne
# ,
# dramatyczne
# .
# Czas
# albo
# dokonać
# głębokiej
# korekty
# ,
# a
# najlepiej
# posłuchać
# tego
# ,
# co
# mówiliśmy
# od
# samego
# początku
# i
# tę
# część
# dotyczącą
# przedsiębiorców
# po
# prostu
# zawiesić
# .
# Dziękuję
# bardzo
# .

# %% [markdown]
# W wyniku otrzymamy objekt reprezentujący cały dokument. Dokumetacja jest dostępna [tutaj](https://spacy.io/api/doc).
#
# Zacznijmy od sprawdzenia jak sobie biblioteka poradziła z podziałem tekstu na zdania. Przeiteruj wszystkie elementy `sents` dokumentu i wypisz metodą print:

# %%
# Out:
# <generator object at 0x7f2a5f821520>

# %%
zdanie = 'To jest opinia Biura Legislacyjnego Sejmu'

# %%
import numpy as np
import pandas as pd

# %%
from spacy.tokens import Doc
docs = list(nlp.pipe(text_sample))
c_doc = Doc.from_docs(docs)
for i in range(len(c_doc)):
  print(c_doc[i])
# Out:
# S
# z
# a
# n
# o
# w
# n
# y
#
# P
# a
# n
# i
# e
#
# M
# a
# r
# s
# z
# a
# ł
# k
# u
# !
#
# W
# y
# s
# o
# k
# a
#
# I
# z
# b
# o
# !
#
# U
# s
# t
# a
# w
# a
#
# z
# a
# p
# o
# w
# i
# a
# d
# a
# n
# a
#
# j
# a
# k
# o
#
# n
# a
# p
# r
# a
# w
# a
# ,
#
# c
# h
# c
# i
# a
# ł
# o
# b
# y
#
# s
# i
# ę
#
# r
# z
# e
# c
# ,
#
# g
# ł
# ę
# b
# o
# k
# a
#
# k
# o
# r
# e
# k
# t
# a
#
# N
# o
# w
# e
# g
# o
#
# Ł
# a
# d
# u
#
# p
# o
# d
# a
# t
# k
# o
# w
# e
# g
# o
#
# p
# o
# z
# a
#
# r
# e
# k
# o
# m
# p
# e
# n
# s
# a
# t
# ą
#
# s
# t
# r
# a
# t
# ,
#
# j
# e
# ś
# l
# i
#
# c
# h
# o
# d
# z
# i
#
# o
#
# z
# a
# k
# ł
# a
# d
# y
#
# p
# r
# a
# c
# y
#
# c
# h
# r
# o
# n
# i
# o
# n
# e
# j
#
# i
#
# z
# a
# k
# ł
# a
# d
# y
#
# a
# k
# t
# y
# w
# n
# o
# ś
# c
# i
#
# z
# a
# w
# o
# d
# o
# w
# e
# j
# ,
#
# t
# o
#
# w
#
# g
# r
# u
# n
# c
# i
# e
#
# r
# z
# e
# c
# z
# y
#
# j
# a
# k
# a
# ś
#
# f
# a
# r
# s
# a
# .
#
# T
# a
# k
#
# n
# a
# p
# r
# a
# w
# d
# ę
#
# t
# o
#
# j
# e
# s
# t
#
# z
# a
# l
# e
# g
# a
# l
# i
# z
# o
# w
# a
# n
# i
# e
#
# r
# o
# z
# p
# o
# r
# z
# ą
# d
# z
# e
# n
# i
# a
#
# m
# i
# n
# i
# s
# t
# r
# a
#
# f
# i
# n
# a
# n
# s
# ó
# w
#
# z
#
# 7
#
# s
# t
# y
# c
# z
# n
# i
# a
#
# 2
# 0
# 2
# 2
#
# r
# .
# ,
#
# r
# o
# z
# p
# o
# r
# z
# ą
# d
# z
# e
# n
# i
# a
#
# w
# y
# d
# a
# n
# e
# g
# o
#
# z
#
# p
# r
# z
# e
# k
# r
# o
# c
# z
# e
# n
# i
# e
# m
#
# d
# e
# l
# e
# g
# a
# c
# j
# i
#
# u
# s
# t
# a
# w
# o
# w
# y
# c
# h
#
# i
#
# n
# a
# r
# u
# s
# z
# e
# n
# i
# e
# m
#
# k
# o
# n
# s
# t
# y
# t
# u
# c
# j
# i
# .
#
# P
# r
# ó
# b
# u
# j
# e
# c
# i
# e
#
# u
# p
# o
# r
# z
# ą
# d
# k
# o
# w
# a
# ć
#
# k
# a
# w
# a
# ł
# e
# k
# ,
#
# u
# ł
# a
# m
# e
# c
# z
# e
# k
#
# p
# r
# o
# b
# l
# e
# m
# ó
# w
# ,
#
# k
# t
# ó
# r
# e
#
# w
#
# t
# y
# m
#
# b
# u
# b
# l
# u
#
# p
# r
# a
# w
# n
# y
# m
# ,
#
# j
# a
# k
# i
# m
#
# j
# e
# s
# t
#
# N
# o
# w
# y
#
# Ł
# a
# d
# ,
#
# w
# y
# g
# e
# n
# e
# r
# o
# w
# a
# l
# i
# ś
# c
# i
# e
# .
#
# P
# o
#
# t
# y
# g
# o
# d
# n
# i
# u
#
# o
# b
# o
# w
# i
# ą
# z
# y
# w
# a
# n
# i
# a
#
# u
# s
# t
# a
# w
# y
#
# o
# k
# a
# z
# a
# ł
# o
#
# s
# i
# ę
# ,
#
# ż
# e
#
# c
# i
# ,
#
# k
# t
# ó
# r
# z
# y
#
# m
# i
# e
# l
# i
#
# z
# y
# s
# k
# i
# w
# a
# ć
# ,
#
# t
# r
# a
# c
# ą
#
# j
# u
# ż
#
# d
# z
# i
# s
# i
# a
# j
# ,
#
# i
# c
# h
#
# w
# y
# p
# ł
# a
# t
# y
#
# s
# ą
#
# n
# i
# ż
# s
# z
# e
# ,
#
# a
#
# m
# i
# a
# ł
# y
#
# b
# y
# ć
#
# p
# r
# z
# e
# c
# i
# e
# ż
#
# w
# y
# ż
# s
# z
# e
# .
#
# D
# o
#
# t
# e
# g
# o
#
# n
# i
# k
# t
#
# n
# i
# e
#
# w
# i
# e
# ,
#
# j
# a
# k
# i
#
# z
# a
# p
# ł
# a
# c
# i
#
# p
# o
# d
# a
# t
# e
# k
# .
#
# T
# o
#
# j
# u
# ż
#
# n
# o
# r
# m
# a
# ,
#
# j
# e
# ś
# l
# i
#
# c
# h
# o
# d
# z
# i
#
# o
#
# w
# a
# s
# z
# e
#
# d
# z
# i
# a
# ł
# a
# n
# i
# a
#
# -
#
# m
# n
# i
# e
# j
#
# z
# n
# a
# c
# z
# y
#
# w
# i
# ę
# c
# e
# j
# ,
#
# j
# a
# k
#
# u
#
# O
# r
# w
# e
# l
# l
# a
# .
#
# T
# o
# ,
#
# c
# o
#
# p
# r
# o
# p
# o
# n
# u
# j
# e
# c
# i
# e
# ,
#
# t
# o
#
# j
# e
# s
# t
#
# z
# w
# y
# k
# ł
# e
#
# m
# y
# d
# l
# e
# n
# i
# e
#
# o
# c
# z
# u
# .
#
# W
#
# s
# p
# r
# a
# w
# i
# e
#
# z
# a
# l
# i
# c
# z
# e
# k
# :
#
# t
# e
# c
# h
# n
# i
# c
# z
# n
# i
# e
#
# r
# z
# e
# c
# z
#
# u
# j
# m
# u
# j
# ą
# c
# ,
#
# p
# ł
# a
# t
# n
# i
# k
#
# b
# ę
# d
# z
# i
# e
#
# o
# b
# l
# i
# c
# z
# a
# ł
#
# w
# y
# s
# o
# k
# o
# ś
# ć
#
# z
# a
# l
# i
# c
# z
# k
# i
#
# w
# e
# d
# ł
# u
# g
#
# z
# a
# s
# a
# d
#
# z
#
# 2
# 0
# 2
# 2
#
# r
# .
# ,
#
# n
# a
# s
# t
# ę
# p
# n
# i
# e
#
# w
# e
# d
# ł
# u
# g
#
# z
# a
# s
# a
# d
#
# z
#
# 2
# 0
# 2
# 1
#
# r
# .
#
# J
# e
# ś
# l
# i
#
# b
# ę
# d
# z
# i
# e
#
# r
# ó
# ż
# n
# i
# c
# a
#
# t
# a
# k
# a
# ,
#
# ż
# e
#
# z
# a
# l
# i
# c
# z
# k
# a
#
# w
# e
# d
# ł
# u
# g
#
# z
# a
# s
# a
# d
#
# z
#
# 2
# 0
# 2
# 2
#
# r
# .
#
# b
# ę
# d
# z
# i
# e
#
# w
# y
# ż
# s
# z
# a
#
# n
# i
# ż
#
# t
# a
#
# z
#
# 2
# 0
# 2
# 1
#
# r
# .
# ,
#
# t
# o
#
# n
# i
# e
#
# b
# ę
# d
# z
# i
# e
#
# p
# o
# b
# i
# e
# r
# a
# ć
#
# t
# e
# j
#
# r
# ó
# ż
# n
# i
# c
# y
# ,
#
# a
#
# d
# e
# f
# i
# n
# i
# t
# y
# w
# n
# e
#
# r
# o
# z
# l
# i
# c
# z
# e
# n
# i
# e
#
# n
# a
# s
# t
# ą
# p
# i
#
# d
# o
# p
# i
# e
# r
# o
#
# w
#
# z
# e
# z
# n
# a
# n
# i
# u
#
# r
# o
# c
# z
# n
# y
# m
# .
#
# T
# a
# k
# i
#
# m
# e
# c
# h
# a
# n
# i
# z
# m
#
# j
# e
# s
# t
#
# s
# p
# o
# s
# o
# b
# e
# m
#
# o
# d
# r
# o
# c
# z
# e
# n
# i
# a
#
# p
# ł
# a
# t
# n
# o
# ś
# c
# i
#
# w
# y
# ż
# s
# z
# e
# j
#
# n
# i
# ż
#
# w
#
# 2
# 0
# 2
# 1
#
# r
# .
#
# z
# a
# l
# i
# c
# z
# k
# i
#
# n
# a
#
# p
# o
# d
# a
# t
# e
# k
# ,
#
# a
# l
# e
#
# n
# i
# e
#
# j
# e
# s
# t
#
# z
# w
# o
# l
# n
# i
# e
# n
# i
# e
# m
#
# p
# o
# d
# a
# t
# n
# i
# k
# a
#
# z
#
# o
# b
# o
# w
# i
# ą
# z
# k
# u
#
# s
# t
# o
# s
# o
# w
# a
# n
# i
# a
#
# p
# r
# z
# e
# p
# i
# s
# ó
# w
#
# z
#
# 2
# 0
# 2
# 2
#
# r
# .
#
# W
#
# p
# r
# a
# k
# t
# y
# c
# e
#
# d
# l
# a
#
# n
# i
# e
# k
# t
# ó
# r
# y
# c
# h
#
# p
# o
# d
# a
# t
# n
# i
# k
# ó
# w
#
# m
# o
# ż
# e
#
# t
# o
#
# o
# z
# n
# a
# c
# z
# a
# ć
#
# k
# o
# n
# i
# e
# c
# z
# n
# o
# ś
# ć
#
# d
# o
# p
# ł
# a
# t
# y
#
# p
# o
# d
# a
# t
# k
# u
#
# w
#
# g
# r
# u
# d
# n
# i
# u
#
# 2
# 0
# 2
# 2
#
# r
# .
#
# a
# l
# b
# o
#
# w
#
# r
# o
# z
# l
# i
# c
# z
# e
# n
# i
# u
#
# r
# o
# c
# z
# n
# y
# m
# .
#
# P
# o
# d
# k
# r
# e
# ś
# l
# a
# m
# ,
#
# t
# e
#
# z
# m
# i
# a
# n
# y
#
# n
# i
# e
#
# p
# r
# o
# w
# a
# d
# z
# ą
#
# d
# o
#
# o
# b
# n
# i
# ż
# e
# n
# i
# a
#
# p
# o
# d
# a
# t
# k
# ó
# w
# ,
#
# a
#
# j
# e
# d
# y
# n
# i
# e
#
# s
# ą
#
# m
# o
# d
# y
# f
# i
# k
# a
# c
# j
# ą
#
# o
# b
# o
# w
# i
# ą
# z
# k
# ó
# w
#
# p
# ł
# a
# t
# n
# i
# k
# ó
# w
#
# i
#
# p
# r
# a
# c
# o
# d
# a
# w
# c
# ó
# w
# ,
#
# z
# l
# e
# c
# e
# n
# i
# o
# d
# a
# w
# c
# ó
# w
#
# i
#
# o
# r
# g
# a
# n
# ó
# w
#
# r
# e
# n
# t
# o
# w
# y
# c
# h
#
# w
#
# z
# a
# k
# r
# e
# s
# i
# e
#
# p
# o
# b
# o
# r
# u
#
# z
# a
# l
# i
# c
# z
# k
# i
#
# n
# a
#
# p
# o
# d
# a
# t
# e
# k
#
# d
# o
# c
# h
# o
# d
# o
# w
# y
#
# o
# d
#
# o
# s
# ó
# b
#
# f
# i
# z
# y
# c
# z
# n
# y
# c
# h
# .
#
# T
# o
#
# j
# e
# s
# t
#
# k
# o
# l
# e
# j
# n
# e
#
# o
# b
# c
# i
# ą
# ż
# e
# n
# i
# e
#
# a
# d
# m
# i
# n
# i
# s
# t
# r
# a
# c
# y
# j
# n
# e
#
# d
# l
# a
#
# p
# ł
# a
# t
# n
# i
# k
# ó
# w
# ,
#
# c
# z
# y
# l
# i
#
# p
# o
# l
# s
# k
# i
# c
# h
#
# p
# r
# z
# e
# d
# s
# i
# ę
# b
# i
# o
# r
# c
# ó
# w
#
# i
#
# i
# c
# h
#
# k
# s
# i
# ę
# g
# o
# w
# y
# c
# h
# .
#
# P
# r
# o
# j
# e
# k
# t
#
# j
# e
# s
# t
#
# n
# a
# p
# i
# s
# a
# n
# y
#
# n
# a
#
# k
# o
# l
# a
# n
# i
# e
#
# -
#
# m
# ó
# w
# i
# ł
# e
# m
#
# t
# o
#
# w
#
# r
# a
# m
# a
# c
# h
#
# p
# i
# e
# r
# w
# s
# z
# e
# g
# o
#
# c
# z
# y
# t
# a
# n
# i
# a
#
# -
#
# i
#
# t
# o
#
# j
# u
# ż
#
# j
# e
# s
# t
#
# j
# a
# k
# a
# ś
#
# t
# r
# a
# d
# y
# c
# j
# a
# .
#
# C
# z
# a
# s
#
# w
# r
# e
# s
# z
# c
# i
# e
#
# p
# r
# z
# e
# j
# ś
# ć
#
# z
#
# d
# e
# k
# l
# a
# r
# a
# c
# j
# i
#
# d
# o
#
# c
# z
# y
# n
# ó
# w
# .
#
# C
# i
# ą
# g
# l
# e
# ,
#
# t
# a
# k
#
# j
# a
# k
#
# p
# r
# e
# z
# y
# d
# e
# n
# t
# ,
#
# m
# ó
# w
# i
# c
# i
# e
# ,
#
# ż
# e
#
# s
# i
# ę
#
# u
# c
# z
# y
# c
# i
# e
# .
#
# A
#
# n
# i
# e
#
# s
# z
# t
# u
# k
# a
#
# s
# i
# ę
#
# u
# c
# z
# y
# ć
# ,
#
# t
# r
# z
# e
# b
# a
#
# s
# i
# ę
#
# n
# a
# u
# c
# z
# y
# ć
#
# i
#
# w
# y
# c
# i
# ą
# g
# a
# ć
#
# l
# e
# k
# c
# j
# e
#
# i
#
# w
# n
# i
# o
# s
# k
# i
#
# z
#
# d
# o
# t
# y
# c
# h
# c
# z
# a
# s
# o
# w
# y
# c
# h
#
# d
# z
# i
# a
# ł
# a
# ń
# .
#
# B
# i
# u
# r
# o
#
# L
# e
# g
# i
# s
# l
# a
# c
# y
# j
# n
# e
#
# p
# o
#
# r
# a
# z
#
# k
# o
# l
# e
# j
# n
# y
#
# z
# ł
# o
# ż
# y
# ł
# o
#
# z
# a
# s
# t
# r
# z
# e
# ż
# e
# n
# i
# e
# ,
#
# ż
# e
#
# n
# i
# e
#
# b
# y
# ł
# o
#
# w
#
# s
# t
# a
# n
# i
# e
#
# p
# r
# z
# e
# a
# n
# a
# l
# i
# z
# o
# w
# a
# ć
#
# z
# a
# p
# i
# s
# ó
# w
#
# u
# s
# t
# a
# w
# y
# ,
#
# w
#
# p
# r
# a
# k
# t
# y
# c
# e
#
# -
#
# ż
# e
#
# n
# i
# e
#
# m
# a
#
# p
# e
# w
# n
# o
# ś
# c
# i
#
# c
# o
#
# d
# o
#
# p
# o
# p
# r
# a
# w
# n
# o
# ś
# c
# i
#
# j
# e
# j
#
# z
# a
# p
# i
# s
# ó
# w
# .
#
# M
# a
# ł
# o
#
# t
# e
# g
# o
# ,
#
# w
#
# u
# s
# t
# a
# w
# i
# e
#
# s
# ą
#
# z
# a
# p
# i
# s
# y
# ,
#
# k
# t
# ó
# r
# e
#
# s
# ą
#
# n
# i
# e
#
# d
# o
#
# z
# a
# a
# k
# c
# e
# p
# t
# o
# w
# a
# n
# i
# a
#
# i
#
# n
# i
# e
#
# d
# o
#
# p
# r
# z
# y
# j
# ę
# c
# i
# a
# .
#
# T
# o
#
# j
# e
# s
# t
#
# o
# p
# i
# n
# i
# a
#
# B
# i
# u
# r
# a
#
# L
# e
# g
# i
# s
# l
# a
# c
# y
# j
# n
# e
# g
# o
#
# S
# e
# j
# m
# u
# .
#
# A
# l
# e
#
# w
# y
#
# o
# c
# z
# y
# w
# i
# ś
# c
# i
# e
#
# w
# s
# z
# y
# s
# t
# k
# o
#
# m
# o
# ż
# e
# c
# i
# e
#
# p
# r
# z
# e
# g
# ł
# o
# s
# o
# w
# a
# ć
# ,
#
# d
# o
# w
# i
# e
# d
# l
# i
# ś
# c
# i
# e
#
# t
# e
# g
# o
#
# w
# c
# z
# o
# r
# a
# j
#
# n
# a
#
# p
# o
# s
# i
# e
# d
# z
# e
# n
# i
# u
#
# k
# o
# m
# i
# s
# j
# i
# .
#
# T
# o
# ,
#
# ż
# e
#
# n
# a
# r
# a
# ż
# a
# c
# i
# e
#
# p
# o
# d
# a
# t
# n
# i
# k
# ó
# w
#
# i
#
# p
# ł
# a
# t
# n
# i
# k
# ó
# w
#
# n
# a
#
# n
# i
# e
# p
# r
# z
# e
# w
# i
# d
# y
# w
# a
# l
# n
# e
#
# d
# z
# i
# ś
#
# k
# o
# n
# s
# e
# k
# w
# e
# n
# c
# j
# e
# ,
#
# n
# i
# e
#
# m
# a
#
# d
# l
# a
#
# w
# a
# s
#
# w
#
# g
# r
# u
# n
# c
# i
# e
#
# r
# z
# e
# c
# z
# y
#
# z
# n
# a
# c
# z
# e
# n
# i
# a
# .
#
# M
# u
# s
# i
#
# b
# y
# ć
#
# t
# a
# k
# ,
#
# j
# a
# k
#
# c
# h
# c
# e
# c
# i
# e
# ,
#
# i
#
# t
# y
# l
# e
# .
#
# W
# c
# z
# o
# r
# a
# j
#
# n
# a
#
# p
# o
# s
# i
# e
# d
# z
# e
# n
# i
# u
#
# k
# o
# m
# i
# s
# j
# i
#
# f
# i
# n
# a
# n
# s
# ó
# w
#
# d
# o
# w
# i
# e
# d
# l
# i
# ś
# c
# i
# e
# ,
#
# ż
# e
#
# n
# i
# e
#
# r
# o
# z
# u
# m
# i
# e
# c
# i
# e
#
# r
# z
# e
# c
# z
# y
# w
# i
# s
# t
# y
# c
# h
#
# s
# k
# u
# t
# k
# ó
# w
#
# N
# o
# w
# e
# g
# o
#
# Ł
# a
# d
# u
# .
#
# N
# i
# e
#
# d
# o
# c
# i
# e
# r
# a
#
# d
# o
#
# w
# a
# s
#
# n
# p
# .
#
# t
# o
# ,
#
# ż
# e
#
# t
# a
# k
#
# n
# a
# p
# r
# a
# w
# d
# ę
#
# z
# l
# i
# k
# w
# i
# d
# o
# w
# a
# l
# i
# ś
# c
# i
# e
#
# k
# w
# o
# t
# ę
#
# w
# o
# l
# n
# ą
# .
#
# O
# n
# a
#
# b
# y
# ł
# a
#
# n
# i
# s
# k
# a
#
# d
# o
#
# t
# e
# j
#
# p
# o
# r
# y
# ,
#
# a
# l
# e
#
# b
# y
# ł
# a
# .
#
# A
#
# d
# z
# i
# s
# i
# a
# j
#
# k
# w
# o
# t
# a
#
# w
# o
# l
# n
# a
#
# w
# y
# n
# o
# s
# i
#
# z
# e
# r
# o
# ,
#
# b
# o
#
# d
# o
# c
# h
# o
# d
# y
#
# d
# o
#
# 3
# 0
#
# t
# y
# s
# .
#
# z
# ł
#
# s
# ą
#
# o
# p
# o
# d
# a
# t
# k
# o
# w
# a
# n
# e
#
# s
# t
# a
# w
# k
# ą
#
# 9
# %
# ,
#
# d
# o
# c
# h
# o
# d
# y
#
# m
# i
# ę
# d
# z
# y
#
# 3
# 0
#
# a
#
# 1
# 2
# 0
#
# t
# y
# s
# .
#
# z
# ł
#
# -
#
# s
# t
# a
# w
# k
# ą
#
# 2
# 6
# %
# ,
#
# a
#
# d
# o
# c
# h
# o
# d
# y
#
# p
# o
# n
# a
# d
#
# 1
# 2
# 0
#
# t
# y
# s
# .
#
# z
# ł
#
# -
#
# s
# t
# a
# w
# k
# ą
#
# 4
# 1
# %
# .
#
# N
# i
# e
#
# z
# a
# p
# o
# m
# i
# n
# a
# j
# c
# i
# e
# ,
#
# ż
# e
#
# p
# o
# d
# a
# t
# n
# i
# c
# y
#
# j
# e
# s
# z
# c
# z
# e
#
# m
# u
# s
# z
# ą
#
# z
# a
# p
# ł
# a
# c
# i
# ć
#
# Z
# U
# S
#
# -
#
# 1
# 9
# ,
# 5
# 2
# %
# .
#
# J
# a
# k
# i
# ś
#
# ł
# o
# ś
#
# w
# a
# s
#
# o
# p
# ę
# t
# a
# ł
# ,
#
# t
# a
# k
# i
# e
#
# m
# a
# m
#
# w
# r
# a
# ż
# e
# n
# i
# e
# .
#
# N
# i
# e
#
# d
# o
# c
# i
# e
# r
# a
#
# d
# o
#
# w
# a
# s
# ,
#
# ż
# e
#
# w
#
# P
# o
# l
# s
# c
# e
#
# p
# r
# z
# e
# s
# t
# a
# ł
# o
#
# s
# i
# ę
#
# j
# u
# ż
# ,
#
# p
# r
# a
# k
# t
# y
# c
# z
# n
# i
# e
#
# r
# z
# e
# c
# z
#
# b
# i
# o
# r
# ą
# c
# ,
#
# o
# p
# ł
# a
# c
# a
# ć
#
# p
# r
# a
# c
# o
# w
# a
# ć
# .
#
# D
# o
#
# t
# e
# g
# o
#
# t
# e
#
# r
# o
# z
# w
# i
# ą
# z
# a
# n
# i
# a
#
# p
# r
# o
# w
# a
# d
# z
# ą
# .
#
# N
# i
# e
#
# m
# a
#
# r
# o
# z
# w
# i
# ą
# z
# a
# ń
# ,
#
# k
# t
# ó
# r
# e
#
# z
# a
# p
# o
# w
# i
# a
# d
# a
# l
# i
# ś
# c
# i
# e
# ,
#
# j
# e
# ś
# l
# i
#
# c
# h
# o
# d
# z
# i
#
# o
#
# k
# o
# r
# e
# k
# t
# ę
#
# N
# o
# w
# e
# g
# o
#
# Ł
# a
# d
# u
# .
#
# N
# i
# e
#
# m
# a
#
# w
#
# d
# a
# l
# s
# z
# y
# m
#
# c
# i
# ą
# g
# u
#
# u
# l
# g
# i
#
# d
# l
# a
#
# k
# l
# a
# s
# y
#
# ś
# r
# e
# d
# n
# i
# e
# j
# ,
#
# d
# l
# a
#
# z
# l
# e
# c
# e
# n
# i
# o
# b
# i
# o
# r
# c
# ó
# w
# ,
#
# d
# l
# a
#
# ś
# w
# i
# a
# d
# c
# z
# e
# ń
#
# e
# m
# e
# r
# y
# t
# a
# l
# n
# y
# c
# h
# ,
#
# r
# e
# n
# t
# o
# w
# y
# c
# h
# .
#
# N
# i
# e
#
# m
# a
#
# ż
# a
# d
# n
# e
# j
#
# p
# r
# o
# p
# o
# z
# y
# c
# j
# i
#
# c
# o
#
# d
# o
#
# r
# o
# z
# l
# i
# c
# z
# a
# n
# i
# a
#
# r
# o
# d
# z
# i
# c
# ó
# w
#
# s
# a
# m
# o
# t
# n
# i
# e
#
# w
# y
# c
# h
# o
# w
# u
# j
# ą
# c
# y
# c
# h
#
# d
# z
# i
# e
# c
# i
# ,
#
# a
#
# t
# a
# k
# ą
#
# d
# e
# k
# l
# a
# r
# a
# c
# j
# ę
#
# t
# e
# ż
#
# s
# ł
# y
# s
# z
# e
# l
# i
# ś
# m
# y
# .
#
# N
# i
# e
#
# m
# a
#
# r
# e
# k
# o
# m
# p
# e
# n
# s
# a
# t
# y
#
# d
# l
# a
#
# o
# r
# g
# a
# n
# i
# z
# a
# c
# j
# i
#
# p
# o
# z
# a
# r
# z
# ą
# d
# o
# w
# y
# c
# h
# .
#
# N
# i
# e
#
# m
# a
#
# p
# r
# o
# p
# o
# z
# y
# c
# j
# i
# ,
#
# o
#
# k
# t
# ó
# r
# e
# j
#
# m
# ó
# w
# i
# ł
#
# t
# e
# ż
#
# p
# r
# e
# m
# i
# e
# r
# :
#
# z
# ł
# o
# t
# ó
# w
# k
# a
#
# z
# a
#
# z
# ł
# o
# t
# ó
# w
# k
# ę
# .
#
# I
#
# n
# i
# e
#
# o
# d
# n
# o
# s
# i
# c
# i
# e
#
# s
# i
# ę
#
# w
#
# o
# g
# ó
# l
# e
#
# d
# o
#
# k
# o
# n
# s
# e
# k
# w
# e
# n
# c
# j
# i
#
# N
# o
# w
# e
# g
# o
#
# Ł
# a
# d
# u
#
# (
# D
# z
# w
# o
# n
# e
# k
# )
#
# w
#
# d
# z
# i
# a
# ł
# a
# l
# n
# o
# ś
# c
# i
#
# g
# o
# s
# p
# o
# d
# a
# r
# c
# z
# e
# j
# ,
#
# a
#
# o
# n
# e
#
# s
# ą
#
# t
# u
#
# d
# r
# a
# m
# a
# t
# y
# c
# z
# n
# e
# ,
#
# d
# r
# a
# m
# a
# t
# y
# c
# z
# n
# e
# .
#
# C
# z
# a
# s
#
# a
# l
# b
# o
#
# d
# o
# k
# o
# n
# a
# ć
#
# g
# ł
# ę
# b
# o
# k
# i
# e
# j
#
# k
# o
# r
# e
# k
# t
# y
# ,
#
# a
#
# n
# a
# j
# l
# e
# p
# i
# e
# j
#
# p
# o
# s
# ł
# u
# c
# h
# a
# ć
#
# t
# e
# g
# o
# ,
#
# c
# o
#
# m
# ó
# w
# i
# l
# i
# ś
# m
# y
#
# o
# d
#
# s
# a
# m
# e
# g
# o
#
# p
# o
# c
# z
# ą
# t
# k
# u
#
# i
#
# t
# ę
#
# c
# z
# ę
# ś
# ć
#
# d
# o
# t
# y
# c
# z
# ą
# c
# ą
#
# p
# r
# z
# e
# d
# s
# i
# ę
# b
# i
# o
# r
# c
# ó
# w
#
# p
# o
#
# p
# r
# o
# s
# t
# u
#
# z
# a
# w
# i
# e
# s
# i
# ć
# .
#
# D
# z
# i
# ę
# k
# u
# j
# ę
#
# b
# a
# r
# d
# z
# o
# .

# %% [markdown]
# Kolejne zadania będą bardziej czytelne jeśli je uruchomimy na pojedynczym zdaniu zamiast całego tekstu. Zamień `sents` na listę i zapisz dowolny element tej listy w osobnej zmiennej `sent`.
#
# Potem przeiteruj kolejne elementy tego zdania żeby odczytać poszczególne tokeny. Dokumentacja tokenu jest [tutaj](https://spacy.io/api/token).
#
# Dla każdego tokenu wypisz:
# * `text`
# * `tag_` - tekstowa postać tagu POS
# * `pos_` - bardziej ogólny opis POS
# * `dep_` - opis parsowania zależnościowego
# * `lemma_` - lemat wyrazu
# * `morp_` - szczegółowy opis morfologii wyrazu

# %%
doc = nlp(text_sample)
for i in range(len(doc)):
  token = doc[i]
  print(token.text, token.tag_, token.pos_, token.dep_, token.lemma_, token.morph)
# Out:
# Szanowny ADJ ADJ amod szanowny Animacy=Hum|Case=Voc|Degree=Pos|Gender=Masc|Number=Sing
# Panie SUBST NOUN ROOT pan Animacy=Hum|Case=Voc|Gender=Masc|Number=Sing
# Marszałku SUBST NOUN appos Marszałek Animacy=Hum|Case=Voc|Gender=Masc|Number=Sing
# ! INTERP PUNCT punct ! PunctType=Excl
# Wysoka ADJ ADJ ROOT wysoki Case=Nom|Degree=Pos|Gender=Fem|Number=Sing
# Izbo SUBST ADJ amod:flat Izbo Case=Nom|Degree=Pos|Gender=Fem|Number=Sing
# ! INTERP PUNCT punct ! PunctType=Excl
# Ustawa SUBST NOUN nsubj ustawa Case=Nom|Gender=Fem|Number=Sing
# zapowiadana PPAS ADJ acl zapowiadać Aspect=Imp|Case=Nom|Gender=Fem|Number=Sing|Polarity=Pos|VerbForm=Part|Voice=Pass
# jako PREP SCONJ mark jako ConjType=Pred
# naprawa SUBST NOUN obl naprawa Case=Nom|Gender=Fem|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# chciałoby FIN VERB ROOT chcieć by Aspect=Imp|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# się QUB PRON expl:pv się PronType=Prs|Reflex=Yes
# rzec INF VERB xcomp rzec Aspect=Perf|VerbForm=Inf|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# głęboka ADJ ADJ amod głęboki Case=Nom|Degree=Pos|Gender=Fem|Number=Sing
# korekta SUBST NOUN conj korekta Case=Nom|Gender=Fem|Number=Sing
# Nowego ADJ ADJ amod:flat Nowy Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
# Ładu SUBST NOUN nmod:arg Ładu Case=Gen|Gender=Fem|Number=Plur
# podatkowego ADJ ADJ amod podatkowy Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
# poza PREP ADP case poza AdpType=Prep
# rekompensatą SUBST NOUN nmod rekompensata Case=Ins|Gender=Fem|Number=Sing
# strat SUBST NOUN nmod:arg strata Case=Gen|Gender=Fem|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# jeśli COMP SCONJ mark jeśli
# chodzi FIN VERB advcl chodzić Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# o PREP ADP case o AdpType=Prep
# zakłady SUBST NOUN obl:arg zakład Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur
# pracy SUBST NOUN nmod:arg praca Case=Gen|Gender=Fem|Number=Sing
# chronionej PPAS ADJ acl chronioć Aspect=Imp|Case=Gen|Gender=Fem|Number=Sing|Polarity=Pos|VerbForm=Part|Voice=Pass
# i CONJ CCONJ cc i
# zakłady SUBST NOUN conj zakład Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur
# aktywności SUBST NOUN nmod:arg aktywność Case=Gen|Gender=Fem|Number=Sing
# zawodowej ADJ ADJ amod zawodowy Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# to CONJ SCONJ mark to
# w PREP ADP parataxis:insert w AdpType=Prep|Variant=Short
# gruncie SUBST NOUN fixed grunt Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# rzeczy SUBST NOUN fixed rzecz Case=Gen|Gender=Fem|Number=Sing
# jakaś ADJ DET det jakiś Case=Nom|Gender=Fem|Number=Sing|PronType=Ind
# farsa SUBST NOUN conj farsa Case=Nom|Gender=Fem|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# Tak ADV PART advmod:emph tak
# naprawdę QUB PART fixed naprawdę
# to PRED AUX nsubj to Mood=Ind|Tense=Pres|VerbForm=Fin|VerbType=Quasi
# jest FIN AUX aux być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# zalegalizowanie GER NOUN ROOT zalegalizować Aspect=Perf|Case=Nom|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# rozporządzenia SUBST NOUN obj rozporządzenie Case=Gen|Gender=Neut|Number=Sing
# ministra SUBST NOUN nmod minister Animacy=Hum|Case=Gen|Gender=Masc|Number=Sing
# finansów SUBST NOUN nmod:arg finanse Case=Gen|Gender=Neut|Number=Ptan
# z PREP ADP case z AdpType=Prep|Variant=Short
# 7 ADJ ADJ nmod:arg 7 Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|NumForm=Digit|NumType=Ord|Number=Sing
# stycznia SUBST NOUN nmod:flat styczeń Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# 2022 ADJ ADJ amod:flat 2022 Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|NumForm=Digit|NumType=Ord|Number=Sing
# r BREV X flat rok Abbr=Yes|Pun=Yes
# . SUBST PUNCT punct . PunctType=Peri
# , INTERP PUNCT punct , PunctType=Comm
# rozporządzenia SUBST NOUN conj rozporządzenie Case=Gen|Gender=Neut|Number=Sing
# wydanego PPAS ADJ acl wydać Aspect=Perf|Case=Gen|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Part|Voice=Pass
# z PREP ADP case z AdpType=Prep|Variant=Short
# przekroczeniem GER NOUN obl:arg przekroczć Aspect=Perf|Case=Ins|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# delegacji SUBST NOUN obj delegacja Case=Gen|Gender=Fem|Number=Plur
# ustawowych ADJ ADJ amod ustawowy Case=Gen|Degree=Pos|Gender=Fem|Number=Plur
# i CONJ CCONJ cc i
# naruszeniem GER NOUN conj naruszyć Aspect=Perf|Case=Ins|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# konstytucji SUBST NOUN obj konstytucja Case=Gen|Gender=Fem|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# Próbujecie FIN VERB ROOT próbujecie Animacy=Hum|Aspect=Imp,Perf|Clitic=Yes|Gender=Masc|Mood=Ind|Number=Plur|Person=2|Tense=Past|Variant=Short|VerbForm=Fin|Voice=Act
# uporządkować INF VERB xcomp uporządkować Aspect=Perf|VerbForm=Inf|Voice=Act
# kawałek SUBST NOUN obj kawałek Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# ułameczek SUBST NOUN conj ułameczek Case=Gen|Gender=Fem|Number=Plur
# problemów SUBST NOUN nmod:arg problem Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# które ADJ DET nsubj który Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur|PronType=Rel
# w PREP ADP case w AdpType=Prep|Variant=Short
# tym ADJ PRON parataxis:insert to Case=Loc|Gender=Neut|Number=Sing|PronType=Dem
# bublu SUBST VERB acl:relcl bublu Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# prawnym ADJ NOUN iobj prawny Animacy=Hum|Case=Dat|Gender=Masc|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# jakim ADJ DET acl:relcl jaki Animacy=Hum|Case=Ins|Gender=Masc|Number=Sing|PronType=Rel
# jest FIN AUX cop być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# Nowy ADJ ADJ amod:flat nowy Animacy=Inan|Case=Nom|Degree=Pos|Gender=Masc|Number=Sing
# Ład SUBST NOUN nsubj Ład Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# wygenerowaliście SUBST PROPN conj wygenerowaliśt Animacy=Hum|Case=Voc|Gender=Masc|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# Po PREP ADP case po AdpType=Prep
# tygodniu SUBST NOUN obl tydzień Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# obowiązywania GER NOUN nmod:arg obowiązywać Aspect=Imp|Case=Gen|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# ustawy SUBST NOUN obj ustawa Case=Gen|Gender=Fem|Number=Sing
# okazało PRAET VERB ROOT okazać Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# się QUB PRON expl:pv się PronType=Prs|Reflex=Yes
# , INTERP PUNCT punct , PunctType=Comm
# że COMP SCONJ mark że
# ci ADJ DET nsubj ten Animacy=Hum|Case=Nom|Gender=Masc|Number=Plur|PronType=Dem
# , INTERP PUNCT punct , PunctType=Comm
# którzy ADJ DET nsubj który Animacy=Hum|Case=Nom|Gender=Masc|Number=Plur|PronType=Rel
# mieli PRAET VERB acl:relcl mieć Animacy=Hum|Aspect=Imp|Gender=Masc|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act
# zyskiwać INF VERB xcomp zyskiwać Aspect=Imp|VerbForm=Inf|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# tracą FIN VERB csubj tracić Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# już QUB PART advmod:emph już
# dzisiaj SUBST ADV advmod dzisiaj
# , INTERP PUNCT punct , PunctType=Comm
# ich PPRON3 PRON nmod on Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur|Person=3|PrepCase=Npr|PronType=Prs|Variant=Long
# wypłaty SUBST NOUN nsubj wypłata Case=Nom|Gender=Fem|Number=Plur
# są FIN AUX cop być Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# niższe ADJ ADJ conj niży Animacy=Inan|Case=Nom|Degree=Cmp|Gender=Masc|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# a CONJ CCONJ cc a
# miały PRAET VERB conj mieć Aspect=Imp|Gender=Fem|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act
# być INF AUX cop być Aspect=Imp|VerbForm=Inf|Voice=Act
# przecież QUB PART advmod:emph przecież
# wyższe ADJ ADJ xcomp wysoki Case=Nom|Degree=Cmp|Gender=Fem|Number=Plur
# . INTERP PUNCT punct . PunctType=Peri
# Do PREP ADP case do AdpType=Prep
# tego SUBST PRON obl:arg to Case=Gen|Gender=Neut|Number=Sing|PronType=Dem
# nikt SUBST PRON nsubj nikt Animacy=Hum|Case=Nom|Gender=Masc|Number=Sing|PronType=Neg
# nie QUB PART advmod:neg nie Polarity=Neg
# wie FIN VERB ROOT wiedzieć Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# jaki ADJ DET obj jaki Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing|PronType=Rel
# zapłaci FIN VERB ccomp zapłacić Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act
# podatek SUBST NOUN obj podatek Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# To PRED AUX cop to Mood=Ind|Tense=Pres|VerbForm=Fin|VerbType=Quasi
# już QUB PART advmod:emph już
# norma SUBST NOUN ROOT norma Case=Nom|Gender=Fem|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# jeśli COMP SCONJ mark jeśli
# chodzi FIN VERB advcl chodzić Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# o PREP ADP case o AdpType=Prep
# wasze ADJ DET det:poss wasz Case=Nom|Gender=Neut|Number=Plur|Number[psor]=Plur|Person=2|Poss=Yes|PronType=Prs
# działania SUBST NOUN obl:arg działanie Case=Acc|Gender=Neut|Number=Plur
# - INTERP PUNCT punct - PunctType=Dash
# mniej ADV ADV dep mniej Degree=Cmp
# znaczy FIN VERB parataxis:insert znaczyć Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# więcej NUM ADV advmod dużo Degree=Cmp
# , INTERP PUNCT punct , PunctType=Comm
# jak ADV SCONJ mark jak ConjType=Comp
# u PREP ADP case u AdpType=Prep
# Orwella SUBST PROPN obl:cmpr Orwell Animacy=Hum|Case=Gen|Gender=Masc|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# To SUBST PRON nsubj to Case=Nom|Gender=Neut|Number=Sing|PronType=Dem
# , INTERP PUNCT punct , PunctType=Comm
# co SUBST PRON obj co Case=Acc|Gender=Neut|Number=Sing|PronType=Rel
# proponujecie IMPT VERB acl:relcl proponować Aspect=Perf|Mood=Ind|Number=Plur|Person=2|Tense=Fut|VerbForm=Fin|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# to PRED AUX cop to Mood=Ind|Tense=Pres|VerbForm=Fin|VerbType=Quasi
# jest FIN AUX aux być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# zwykłe ADJ ADJ amod zwykły Case=Nom|Degree=Pos|Gender=Neut|Number=Sing
# mydlenie GER NOUN ROOT mydleć Aspect=Imp|Case=Nom|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# oczu SUBST NOUN nmod:arg oko Case=Gen|Gender=Neut|NumType=Sets|Number=Plur
# . INTERP PUNCT punct . PunctType=Peri
# W PREP ADP case w AdpType=Prep|Variant=Short
# sprawie SUBST NOUN fixed sprawa Case=Loc|Gender=Fem|Number=Sing
# zaliczek SUBST NOUN ROOT zaliczka Case=Gen|Gender=Fem|Number=Plur
# : INTERP PUNCT punct : PunctType=Colo
# technicznie ADV ADV advmod technicznie Degree=Pos
# rzecz SUBST NOUN obj rzecz Case=Acc|Gender=Fem|Number=Sing
# ujmując ADJ VERB advcl ujmuć Aspect=Imp|Tense=Pres|VerbForm=Conv|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# płatnik SUBST NOUN nsubj płatnik Animacy=Hum|Case=Nom|Gender=Masc|Number=Sing
# będzie BEDZIE AUX aux być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin
# obliczał PRAET VERB ccomp obliczać Animacy=Hum|Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# wysokość SUBST NOUN obj wysokość Case=Acc|Gender=Fem|Number=Sing
# zaliczki SUBST NOUN nmod zaliczka Case=Gen|Gender=Fem|Number=Sing
# według PREP ADP case według AdpType=Prep
# zasad SUBST NOUN nmod zasada Case=Gen|Gender=Fem|Number=Plur
# z PREP ADP case z AdpType=Prep|Variant=Short
# 2022 ADJ ADJ amod:flat 2022 Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|NumForm=Digit|NumType=Ord|Number=Sing
# r BREV X nmod rok Abbr=Yes|Pun=Yes
# . SUBST PUNCT punct . PunctType=Peri
# , INTERP PUNCT punct , PunctType=Comm
# następnie ADV ADV advmod następnie
# według PREP ADP case według AdpType=Prep
# zasad SUBST NOUN conj zasada Case=Gen|Gender=Fem|Number=Plur
# z PREP ADP case z AdpType=Prep|Variant=Short
# 2021 ADJ ADJ amod:flat 2021 Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|NumForm=Digit|NumType=Ord|Number=Sing
# r SUBST X nmod rok Abbr=Yes|Pun=Yes
# . INTERP PUNCT punct . PunctType=Peri
# Jeśli COMP SCONJ mark jeśli
# będzie BEDZIE VERB advcl być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin
# różnica SUBST NOUN nsubj różnica Case=Nom|Gender=Fem|Number=Sing
# taka ADJ DET ROOT taki Case=Nom|Gender=Fem|Number=Sing|PronType=Dem
# , INTERP PUNCT punct , PunctType=Comm
# że COMP SCONJ mark że
# zaliczka SUBST NOUN nsubj zaliczka Case=Nom|Gender=Fem|Number=Sing
# według PREP ADP case według AdpType=Prep
# zasad SUBST NOUN nmod zasada Case=Gen|Gender=Fem|Number=Plur
# z PREP ADP case z AdpType=Prep|Variant=Short
# 2022 ADJ ADJ amod:flat 2022 Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|NumForm=Digit|NumType=Ord|Number=Sing
# r BREV X nmod rok Abbr=Yes|Pun=Yes
# . INTERP PUNCT punct . PunctType=Peri
# będzie BEDZIE AUX cop być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin
# wyższa ADJ ADJ ccomp wysoki Case=Nom|Degree=Cmp|Gender=Fem|Number=Sing
# niż PREP SCONJ mark niż ConjType=Comp
# ta ADJ DET obl:cmpr ten Case=Nom|Gender=Fem|Number=Sing|PronType=Dem
# z PREP ADP case z AdpType=Prep|Variant=Short
# 2021 ADJ ADJ amod:flat 2021 Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|NumForm=Digit|NumType=Ord|Number=Sing
# r BREV X nmod rok Abbr=Yes|Pun=Yes
# . SUBST PUNCT punct . PunctType=Peri
# , INTERP PUNCT punct , PunctType=Comm
# to CONJ SCONJ mark to
# nie QUB PART advmod:neg nie Polarity=Neg
# będzie BEDZIE AUX aux być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin
# pobierać INF VERB conj pobierać Aspect=Imp|VerbForm=Inf|Voice=Act
# tej ADJ DET det ten Case=Gen|Gender=Fem|Number=Sing|PronType=Dem
# różnicy SUBST NOUN obj różnica Case=Gen|Gender=Fem|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# a CONJ CCONJ cc a
# definitywne ADJ ADJ amod definitywny Case=Nom|Degree=Pos|Gender=Neut|Number=Sing
# rozliczenie SUBST NOUN nsubj rozliczenie Case=Acc|Gender=Neut|Number=Sing
# nastąpi FIN VERB conj nastąpić Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act
# dopiero QUB PART advmod:emph dopiero
# w PREP ADP case w AdpType=Prep|Variant=Short
# zeznaniu SUBST NOUN obl zeznanie Case=Loc|Gender=Neut|Number=Sing
# rocznym ADJ ADJ amod roczny Case=Loc|Degree=Pos|Gender=Neut|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# Taki ADJ DET det taki Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing|PronType=Dem
# mechanizm SUBST NOUN nsubj mechanizm Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# jest FIN AUX cop być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# sposobem SUBST NOUN ROOT sposób Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing
# odroczenia GER NOUN nmod:arg odroczyć Aspect=Perf|Case=Gen|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# płatności SUBST NOUN obj płatność Case=Gen|Gender=Fem|Number=Sing
# wyższej ADJ ADJ amod wyższy Case=Gen|Degree=Cmp|Gender=Fem|Number=Sing
# niż CONJ SCONJ mark niż ConjType=Comp
# w PREP ADP case w AdpType=Prep|Variant=Short
# 2021 ADJ ADJ amod:flat 2021 Animacy=Inan|Case=Loc|Degree=Pos|Gender=Masc|NumForm=Digit|NumType=Ord|Number=Sing
# r BREV X obl:cmpr rok Abbr=Yes|Pun=Yes
# . INTERP PUNCT punct . PunctType=Peri
# zaliczki SUBST NOUN ROOT zaliczka Case=Nom|Gender=Fem|Number=Plur
# na PREP ADP case na AdpType=Prep
# podatek SUBST NOUN nmod podatek Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# ale CONJ CCONJ cc ale
# nie QUB PART advmod:neg nie Polarity=Neg
# jest FIN AUX cop być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# zwolnieniem GER NOUN conj zwolnienie Case=Ins|Gender=Neut|Number=Sing
# podatnika SUBST NOUN obj podatnik Animacy=Hum|Case=Gen|Gender=Masc|Number=Sing
# z PREP ADP case z AdpType=Prep|Variant=Short
# obowiązku SUBST NOUN obl:arg obowiązek Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# stosowania GER NOUN nmod:arg stosować Aspect=Imp|Case=Gen|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# przepisów SUBST NOUN obj przepis Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# z PREP ADP case z AdpType=Prep|Variant=Short
# 2022 ADJ ADJ amod:flat 2022 Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|NumForm=Digit|NumType=Ord|Number=Sing
# r BREV X nmod rok Abbr=Yes|Pun=Yes
# . INTERP PUNCT punct . PunctType=Peri
# W PREP ADP case w AdpType=Prep|Variant=Short
# praktyce SUBST NOUN obl praktyka Case=Loc|Gender=Fem|Number=Sing
# dla PREP ADP case dla AdpType=Prep
# niektórych ADJ ADJ det niektóry Animacy=Hum|Case=Gen|Degree=Pos|Gender=Masc|Number=Plur
# podatników SUBST NOUN nmod podatnik Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur
# może FIN VERB ROOT móc Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# to SUBST PRON nsubj to Case=Nom|Gender=Neut|Number=Sing|PronType=Dem
# oznaczać INF VERB xcomp oznaczać Aspect=Imp|VerbForm=Inf|Voice=Act
# konieczność SUBST NOUN obj konieczność Case=Acc|Gender=Fem|Number=Sing
# dopłaty SUBST NOUN nmod:arg dopłata Case=Gen|Gender=Fem|Number=Sing
# podatku SUBST NOUN nmod:arg podatek Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# w PREP ADP case w AdpType=Prep|Variant=Short
# grudniu SUBST NOUN nmod grudzień Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# 2022 ADJ ADJ amod:flat 2022 Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|NumForm=Digit|NumType=Ord|Number=Sing
# r BREV X flat rok Abbr=Yes|Pun=Yes
# . INTERP PUNCT punct . PunctType=Peri
# albo CONJ CCONJ cc albo
# w PREP ADP case w AdpType=Prep|Variant=Short
# rozliczeniu SUBST NOUN conj rozliczenie Case=Loc|Gender=Neut|Number=Sing
# rocznym ADJ ADJ amod roczny Case=Loc|Degree=Pos|Gender=Neut|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# Podkreślam SUBST VERB parataxis:insert podkreślać Aspect=Imp|Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# te ADJ DET det ten Case=Acc|Gender=Fem|Number=Plur|PronType=Dem
# zmiany SUBST NOUN obj zmiana Case=Nom|Gender=Fem|Number=Plur
# nie QUB PART advmod:neg nie Polarity=Neg
# prowadzą FIN VERB ROOT prowadzić Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# do PREP ADP case do AdpType=Prep
# obniżenia GER NOUN obl obniżeć Aspect=Perf|Case=Gen|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# podatków SUBST NOUN obj podatek Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# a CONJ CCONJ cc a
# jedynie QUB PART advmod:emph jedynie
# są FIN AUX cop być Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# modyfikacją SUBST NOUN conj modyfikacja Case=Ins|Gender=Fem|Number=Sing
# obowiązków SUBST NOUN nmod:arg obowiązek Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# płatników SUBST NOUN nmod płatnik Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur
# i CONJ CCONJ cc i
# pracodawców SUBST NOUN conj pracodawca Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# zleceniodawców SUBST NOUN conj zleceniodawca Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur
# i CONJ CCONJ cc i
# organów SUBST NOUN conj organ Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# rentowych ADJ ADJ amod rentowy Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|Number=Plur
# w PREP ADP case w AdpType=Prep|Variant=Short
# zakresie SUBST NOUN fixed zakres Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# poboru SUBST NOUN nmod pobór Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# zaliczki SUBST NOUN nmod:arg zaliczka Case=Gen|Gender=Fem|Number=Sing
# na PREP ADP case na AdpType=Prep
# podatek SUBST NOUN nmod:arg podatek Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# dochodowy ADJ ADJ amod dochodowy Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing
# od PREP ADP case od AdpType=Prep|Variant=Short
# osób SUBST NOUN nmod osoba Case=Gen|Gender=Fem|Number=Plur
# fizycznych ADJ ADJ amod fizyczny Case=Gen|Degree=Pos|Gender=Fem|Number=Plur
# . INTERP PUNCT punct . PunctType=Peri
# To PRED AUX cop to Mood=Ind|Tense=Pres|VerbForm=Fin|VerbType=Quasi
# jest FIN AUX aux być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# kolejne ADJ ADJ amod kolejny Case=Nom|Degree=Pos|Gender=Neut|Number=Sing
# obciążenie SUBST NOUN ROOT obciążenie Case=Nom|Gender=Neut|Number=Sing
# administracyjne ADJ ADJ amod administracyjny Case=Nom|Degree=Pos|Gender=Neut|Number=Sing
# dla PREP ADP case dla AdpType=Prep
# płatników SUBST NOUN nmod płatnik Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# czyli CONJ CCONJ cc czyli
# polskich ADJ ADJ amod polski Animacy=Hum|Case=Acc|Degree=Pos|Gender=Masc|Number=Plur
# przedsiębiorców SUBST NOUN conj przedsiębiorca Animacy=Hum|Case=Acc|Gender=Masc|Number=Plur
# i CONJ CCONJ cc i
# ich PPRON3 PRON nmod on Case=Gen|Gender=Fem|Number=Plur|Person=3|PrepCase=Npr|PronType=Prs|Variant=Long
# księgowych SUBST ADJ conj księgowy Animacy=Hum|Case=Acc|Degree=Pos|Gender=Masc|Number=Plur
# . INTERP PUNCT punct . PunctType=Peri
# Projekt SUBST NOUN nsubj:pass projekt Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# jest FIN AUX aux:pass być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# napisany PPAS ADJ ROOT napisać Animacy=Inan|Aspect=Perf|Case=Nom|Gender=Masc|Number=Sing|Polarity=Pos|VerbForm=Part|Voice=Pass
# na PREP ADP case na AdpType=Prep
# kolanie SUBST NOUN obl kolan Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# - INTERP PUNCT punct - PunctType=Dash
# mówiłem IMPT VERB conj mówić być Animacy=Hum|Aspect=Imp|Clitic=Yes|Gender=Masc|Mood=Ind|Number=Sing|Person=1|Tense=Past|Variant=Long|VerbForm=Fin|Voice=Act
# to SUBST PRON obj to Case=Acc|Gender=Neut|Number=Sing|PronType=Dem
# w PREP ADP case w AdpType=Prep|Variant=Short
# ramach SUBST NOUN fixed ramy Case=Loc|Gender=Neut|Number=Ptan
# pierwszego ADJ ADJ amod pierwszy Case=Gen|Degree=Pos|Gender=Neut|Number=Sing
# czytania SUBST NOUN obl czytać Aspect=Imp|Case=Gen|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# - INTERP PUNCT punct - PunctType=Dash
# i CONJ CCONJ cc i
# to PRED AUX cop to Mood=Ind|Tense=Pres|VerbForm=Fin|VerbType=Quasi
# już QUB PART advmod:emph już
# jest FIN AUX aux być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# jakaś ADJ DET det jakiś Case=Nom|Gender=Fem|Number=Sing|PronType=Ind
# tradycja SUBST NOUN conj tradycja Case=Nom|Gender=Fem|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# Czas PRED NOUN ROOT czas Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# wreszcie ADV PART advmod:emph wreszcie
# przejść INF VERB xcomp przejść Aspect=Perf|VerbForm=Inf|Voice=Act
# z PREP ADP case z AdpType=Prep|Variant=Short
# deklaracji SUBST NOUN obl:arg deklaracja Case=Gen|Gender=Fem|Number=Sing
# do PREP ADP case do AdpType=Prep
# czynów SUBST NOUN nmod:arg czyn Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# . INTERP PUNCT punct . PunctType=Peri
# Ciągle ADV ADV advmod ciągle Degree=Pos
# , INTERP PUNCT punct , PunctType=Comm
# tak ADV ADV advmod tak Degree=Pos|PronType=Dem
# jak ADV SCONJ mark jak ConjType=Comp
# prezydent SUBST NOUN obl:cmpr prezydent Animacy=Hum|Case=Nom|Gender=Masc|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# mówicie FIN VERB ROOT mówić Aspect=Imp|Mood=Ind|Number=Plur|Person=2|Tense=Pres|VerbForm=Fin|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# że COMP SCONJ mark że
# się QUB PRON expl:pv się PronType=Prs|Reflex=Yes
# uczycie FIN VERB ccomp uczyć Aspect=Imp|Mood=Ind|Number=Plur|Person=2|Tense=Pres|VerbForm=Fin|Voice=Act
# . INTERP PUNCT punct . PunctType=Peri
# A CONJ PART cc a
# nie QUB PART advmod:neg nie Polarity=Neg
# sztuka SUBST NOUN ROOT sztuka Case=Nom|Gender=Fem|Number=Sing
# się QUB PRON expl:pv się PronType=Prs|Reflex=Yes
# uczyć INF VERB xcomp uczyć Aspect=Imp|VerbForm=Inf|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# trzeba PRED VERB conj trzeba Mood=Ind|Tense=Pres|VerbForm=Fin|VerbType=Quasi
# się QUB PRON expl:pv się PronType=Prs|Reflex=Yes
# nauczyć INF VERB xcomp nauczyć Aspect=Perf|VerbForm=Inf|Voice=Act
# i CONJ CCONJ cc i
# wyciągać INF VERB conj wyciągać Aspect=Imp|VerbForm=Inf|Voice=Act
# lekcje SUBST NOUN obj lekcja Case=Acc|Gender=Fem|Number=Plur
# i CONJ CCONJ cc i
# wnioski SUBST NOUN conj wniosek Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur
# z PREP ADP case z AdpType=Prep|Variant=Short
# dotychczasowych ADJ ADJ amod dotychczasowy Case=Gen|Degree=Pos|Gender=Neut|Number=Plur
# działań SUBST NOUN nmod działanie Case=Gen|Gender=Neut|Number=Plur
# . INTERP PUNCT punct . PunctType=Peri
# Biuro SUBST NOUN nsubj biuro Case=Nom|Gender=Neut|Number=Sing
# Legislacyjne ADJ ADJ amod:flat Legislacyjne Case=Nom|Degree=Pos|Gender=Neut|Number=Sing
# po PREP ADP case po AdpType=Prep
# raz SUBST NOUN obl raz Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# kolejny ADJ ADJ amod kolejny Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Sing
# złożyło PRAET VERB ROOT złożyć Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# zastrzeżenie SUBST NOUN obj zastrzeżenie Case=Acc|Gender=Neut|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# że COMP SCONJ mark że
# nie QUB PART advmod:neg nie Polarity=Neg
# było PRAET VERB ccomp być Aspect=Imp|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# w PREP ADP case w AdpType=Prep|Variant=Short
# stanie SUBST NOUN obl:arg stan Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# przeanalizować INF VERB xcomp przeanalizować Aspect=Perf|VerbForm=Inf|Voice=Act
# zapisów SUBST NOUN obj zapis Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# ustawy SUBST NOUN nmod ustawa Case=Gen|Gender=Fem|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# w PREP ADP case w AdpType=Prep|Variant=Short
# praktyce SUBST NOUN obl praktyka Case=Loc|Gender=Fem|Number=Sing
# - INTERP PUNCT punct - PunctType=Dash
# że COMP SCONJ mark że
# nie QUB PART advmod:neg nie Polarity=Neg
# ma FIN VERB conj mieć Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# pewności SUBST NOUN iobj pewność Case=Gen|Gender=Fem|Number=Sing
# co COMP SCONJ mark co
# do PREP ADP case do AdpType=Prep
# poprawności SUBST NOUN nmod:arg poprawność Case=Gen|Gender=Fem|Number=Sing
# jej PPRON3 PRON nmod on Case=Gen|Gender=Fem|Number=Sing|Person=3|PrepCase=Npr|PronType=Prs|Variant=Long
# zapisów SUBST NOUN nmod:arg zapis Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# . INTERP PUNCT punct . PunctType=Peri
# Mało NUM ADV det:numgov mało Degree=Pos
# tego SUBST PRON ROOT to Case=Gen|Gender=Neut|Number=Sing|PronType=Dem
# , INTERP PUNCT punct , PunctType=Comm
# w PREP ADP case w AdpType=Prep|Variant=Short
# ustawie SUBST NOUN nmod ustawa Case=Loc|Gender=Fem|Number=Sing
# są FIN AUX cop być Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# zapisy SUBST NOUN nsubj zapis Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# które ADJ DET nsubj który Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur|PronType=Rel
# są FIN AUX acl:relcl być Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# nie QUB PART advmod:neg nie Polarity=Neg
# do PREP ADP case do AdpType=Prep
# zaakceptowania GER NOUN obl:arg zaakceptować Aspect=Perf|Case=Gen|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# i CONJ CCONJ cc i
# nie QUB PART advmod:neg nie Polarity=Neg
# do PREP ADP case do AdpType=Prep
# przyjęcia SUBST NOUN conj przyjąć Aspect=Perf|Case=Gen|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# . INTERP PUNCT punct . PunctType=Peri
# To PRED AUX cop to Mood=Ind|Tense=Pres|VerbForm=Fin|VerbType=Quasi
# jest FIN AUX aux być Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# opinia SUBST NOUN ROOT opinia Case=Nom|Gender=Fem|Number=Sing
# Biura SUBST NOUN nmod biuro Case=Gen|Gender=Neut|Number=Sing
# Legislacyjnego ADJ ADJ amod:flat legislacyjny Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
# Sejmu SUBST NOUN nmod:flat sejm Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# Ale CONJ CCONJ cc ale
# wy PPRON12 PRON nsubj wy Animacy=Hum|Case=Nom|Gender=Masc|Number=Plur|Person=2|PronType=Prs
# oczywiście QUB ADV parataxis:insert oczywiście Degree=Pos
# wszystko SUBST PRON obj wszystko Case=Acc|Gender=Neut|Number=Sing|PronType=Tot
# możecie FIN VERB ROOT móc Aspect=Imp|Mood=Ind|Number=Plur|Person=2|Tense=Pres|VerbForm=Fin|Voice=Act
# przegłosować INF VERB xcomp przegłosować Aspect=Perf|VerbForm=Inf|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# dowiedliście IMPT VERB conj dowiedliść Aspect=Imp|Mood=Imp|Number=Plur|Person=2|VerbForm=Fin|Voice=Act
# tego SUBST PRON obj to Case=Gen|Gender=Neut|Number=Sing|PronType=Dem
# wczoraj ADV ADV advmod wczoraj
# na PREP ADP case na AdpType=Prep
# posiedzeniu SUBST NOUN obl posiedzenie Case=Loc|Gender=Neut|Number=Sing
# komisji SUBST NOUN nmod komisja Case=Gen|Gender=Fem|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# To SUBST PRON ROOT to Case=Nom|Gender=Neut|Number=Sing|PronType=Dem
# , INTERP PUNCT punct , PunctType=Comm
# że COMP SCONJ mark że
# narażacie GER VERB ccomp:cleft narażata Aspect=Imp|Mood=Ind|Number=Plur|Person=2|Tense=Pres|VerbForm=Fin|Voice=Act
# podatników SUBST NOUN obj podatnik Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur
# i CONJ CCONJ cc i
# płatników SUBST NOUN conj płatnik Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur
# na PREP ADP case na AdpType=Prep
# nieprzewidywalne ADJ ADJ amod nieprzewidywalny Animacy=Inan|Case=Acc|Degree=Pos|Gender=Masc|Number=Plur
# dziś ADV ADV advmod dziś
# konsekwencje SUBST NOUN obl:arg konsekwencja Case=Acc|Gender=Fem|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# nie QUB PART advmod:neg nie Polarity=Neg
# ma FIN VERB conj mieć Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# dla PREP ADP case dla AdpType=Prep
# was PPRON12 PRON obl wy Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur|Person=2|PronType=Prs
# w PREP ADP advmod w AdpType=Prep|Variant=Short
# gruncie SUBST NOUN fixed grunt Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# rzeczy SUBST NOUN fixed rzecz Case=Gen|Gender=Fem|Number=Sing
# znaczenia SUBST NOUN nmod:arg znaczenie Case=Gen|Gender=Neut|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# Musi FIN VERB ROOT musieć Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# być INF VERB xcomp być Aspect=Imp|VerbForm=Inf|Voice=Act
# tak ADV ADV advmod:arg tak Degree=Pos|PronType=Dem
# , INTERP PUNCT punct , PunctType=Comm
# jak ADV SCONJ mark jak ConjType=Comp
# chcecie FIN VERB advcl:cmpr chcecie Aspect=Imp|Mood=Ind|Number=Plur|Person=2|Tense=Pres|VerbForm=Fin|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# i CONJ CCONJ cc i
# tyle NUM ADV conj tyle
# . INTERP PUNCT punct . PunctType=Peri
# Wczoraj ADV ADV advmod wczoraj
# na PREP ADP case na AdpType=Prep
# posiedzeniu SUBST NOUN obl posiedzenie Case=Loc|Gender=Neut|Number=Sing
# komisji SUBST NOUN nmod komisja Case=Gen|Gender=Fem|Number=Sing
# finansów SUBST NOUN nmod finanse Case=Gen|Gender=Neut|Number=Ptan
# dowiedliście SUBST VERB ROOT dowiedliść Aspect=Imp|Mood=Ind|Number=Plur|Person=2|Tense=Pres|VerbForm=Fin|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# że COMP SCONJ mark że
# nie QUB PART advmod:neg nie Polarity=Neg
# rozumiecie FIN VERB ccomp rozumiecie Aspect=Imp|Mood=Imp|Number=Plur|Person=2|VerbForm=Fin|Voice=Act
# rzeczywistych ADJ ADJ amod rzeczywisty Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|Number=Plur
# skutków SUBST NOUN obj skutek Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur
# Nowego ADJ ADJ amod:flat nowy Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
# Ładu SUBST NOUN nmod Ładu Case=Gen|Gender=Fem|Number=Plur
# . INTERP PUNCT punct . PunctType=Peri
# Nie QUB PART advmod:neg nie Polarity=Neg
# dociera FIN VERB ROOT docierać Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# do PREP ADP case do AdpType=Prep
# was PPRON12 PRON obl wy Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur|Person=2|PronType=Prs
# np BREV X parataxis:insert na przykład Abbr=Yes|Pun=Yes
# . INTERP PUNCT punct . PunctType=Peri
# to SUBST PRON nsubj to Case=Nom|Gender=Neut|Number=Sing|PronType=Dem
# , INTERP PUNCT punct , PunctType=Comm
# że COMP SCONJ mark że
# tak ADV PART advmod tak
# naprawdę QUB PART advmod:emph naprawdę
# zlikwidowaliście IMPT VERB ccomp:cleft zlikwidować być Animacy=Hum|Aspect=Imp|Clitic=Yes|Gender=Masc|Mood=Ind|Number=Plur|Person=2|Tense=Past|Variant=Short|VerbForm=Fin|Voice=Act
# kwotę SUBST NOUN obj kwota Case=Acc|Gender=Fem|Number=Sing
# wolną ADJ ADJ amod wolny Case=Acc|Degree=Pos|Gender=Fem|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# Ona PPRON3 PRON nsubj on Case=Nom|Gender=Fem|Number=Sing|Person=3|PrepCase=Npr|PronType=Prs|Variant=Long
# była PRAET AUX cop być Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# niska ADJ ADJ ROOT niski Case=Nom|Degree=Pos|Gender=Fem|Number=Sing
# do PREP ADP case do AdpType=Prep
# tej ADJ DET det ten Case=Gen|Gender=Fem|Number=Sing|PronType=Dem
# pory SUBST NOUN obl pora Case=Gen|Gender=Fem|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# ale CONJ CCONJ cc ale
# była PRAET VERB conj być Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# . INTERP PUNCT punct . PunctType=Peri
# A CONJ PART cc a
# dzisiaj ADV ADV advmod dzisiaj
# kwota SUBST NOUN nsubj kwota Case=Nom|Gender=Fem|Number=Sing
# wolna ADJ ADJ amod wolny Case=Nom|Degree=Pos|Gender=Fem|Number=Sing
# wynosi FIN VERB ROOT wynosić Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# zero SUBST NOUN iobj zero Case=Acc|Gender=Neut|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# bo COMP SCONJ mark bo
# dochody SUBST NOUN nsubj:pass dochód Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur
# do PREP ADP case do AdpType=Prep
# 30 NUM NUM nummod 30 Animacy=Inan|Case=Gen|Gender=Masc|NumForm=Digit|NumType=Card|Number=Plur
# tys BREV X flat tysiąc Abbr=Yes|Pun=Yes
# . INTERP PUNCT punct . PunctType=Peri
# zł BREV X nmod złoty Abbr=Yes|Pun=No
# są FIN AUX aux:pass być Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# opodatkowane PPAS ADJ advcl opodatkować Aspect=Imp|Case=Nom|Gender=Fem|Number=Plur|Polarity=Pos|VerbForm=Part|Voice=Pass
# stawką SUBST NOUN iobj stawka Case=Ins|Gender=Fem|Number=Sing
# 9 NUM NUM nummod:gov 9 Animacy=Inan|Case=Nom|Gender=Masc|NumForm=Digit|NumType=Card|Number=Plur
# % SUBST SYM nmod %
# , INTERP PUNCT punct , PunctType=Comm
# dochody SUBST NOUN conj dochód Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur
# między PREP ADP case między AdpType=Prep
# 30 NUM ADJ nummod:gov 30 Animacy=Inan|Case=Ins|Degree=Pos|Gender=Masc|NumForm=Digit|NumType=Ord|Number=Sing
# a CONJ CCONJ cc a
# 120 NUM NUM nummod:gov 120 Animacy=Inan|Case=Acc|Gender=Masc|NumForm=Digit|NumType=Card|Number=Plur
# tys BREV X flat tysiąc Abbr=Yes|Pun=Yes
# . INTERP PUNCT punct . PunctType=Peri
# zł BREV X nmod złoty Abbr=Yes|Pun=No
# - INTERP PUNCT punct - PunctType=Dash
# stawką SUBST NOUN iobj stawka Case=Ins|Gender=Fem|Number=Sing
# 26 NUM NUM nummod:gov 26 Animacy=Inan|Case=Nom|Gender=Masc|NumForm=Digit|NumType=Card|Number=Plur
# % SUBST SYM nmod %
# , INTERP PUNCT punct , PunctType=Comm
# a CONJ CCONJ cc a
# dochody SUBST NOUN conj dochód Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur
# ponad QUB PART advmod:emph ponad
# 120 NUM NUM nummod 120 Animacy=Inan|Case=Nom|Gender=Masc|NumForm=Digit|NumType=Card|Number=Plur
# tys BREV X flat tysiąc Abbr=Yes|Pun=Yes
# . INTERP PUNCT punct . PunctType=Peri
# zł BREV X nmod złoty Abbr=Yes|Pun=No
# - INTERP PUNCT punct - PunctType=Dash
# stawką SUBST NOUN conj stawka Case=Ins|Gender=Fem|Number=Sing
# 41 NUM NUM nummod:gov 41 Animacy=Inan|Case=Nom|Gender=Masc|NumForm=Digit|NumType=Card|Number=Plur
# % SUBST SYM nmod %
# . INTERP PUNCT punct . PunctType=Peri
# Nie QUB PART advmod:neg nie Polarity=Neg
# zapominajcie IMPT VERB ROOT zapominać Aspect=Imp|Mood=Imp|Number=Plur|Person=2|VerbForm=Fin|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# że COMP SCONJ mark że
# podatnicy SUBST NOUN nsubj podatnik Animacy=Hum|Case=Nom|Gender=Masc|Number=Plur
# jeszcze QUB PART advmod:emph jeszcze
# muszą FIN VERB ccomp:obj musieć Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# zapłacić INF VERB xcomp zapłacić Aspect=Perf|VerbForm=Inf|Voice=Act
# ZUS SUBST PROPN obj ZUS Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing
# - INTERP PUNCT punct - PunctType=Dash
# 19,52 NUM NUM nummod:gov 19,52 Animacy=Inan|Case=Nom|Gender=Masc|NumForm=Digit|NumType=Card|Number=Plur
# % SUBST SYM conj %
# . INTERP PUNCT punct . PunctType=Peri
# Jakiś ADJ DET det jakiś Animacy=Hum|Case=Nom|Gender=Masc|Number=Sing|PronType=Ind
# łoś SUBST NOUN nsubj łoś Animacy=Nhum|Case=Nom|Gender=Masc|Number=Sing
# was PPRON12 PRON obj wy Animacy=Hum|Case=Acc|Gender=Masc|Number=Plur|Person=2|PronType=Prs
# opętał PRAET VERB ROOT opętać Animacy=Hum|Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# takie ADJ DET iobj taki Case=Acc|Gender=Fem|Number=Plur|PronType=Dem
# mam FIN VERB conj mieć Aspect=Imp|Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin|Voice=Act
# wrażenie SUBST NOUN iobj wrażenie Case=Acc|Gender=Neut|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# Nie QUB PART advmod:neg nie Polarity=Neg
# dociera FIN VERB ROOT docierać Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# do PREP ADP case do AdpType=Prep
# was PPRON12 PRON obl wy Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur|Person=2|PronType=Prs
# , INTERP PUNCT punct , PunctType=Comm
# że COMP SCONJ mark że
# w PREP ADP case w AdpType=Prep|Variant=Short
# Polsce SUBST PROPN obl Polska Case=Loc|Gender=Fem|Number=Sing
# przestało PRAET VERB ccomp przestać Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# się QUB PRON expl:pv się PronType=Prs|Reflex=Yes
# już QUB PART advmod:emph już
# , INTERP PUNCT punct , PunctType=Comm
# praktycznie ADV ADV advmod praktycznie Degree=Pos
# rzecz SUBST NOUN obj rzecz Case=Acc|Gender=Fem|Number=Sing
# biorąc ADJ VERB parataxis:insert brać Aspect=Imp|Tense=Pres|VerbForm=Conv|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# opłacać INF VERB xcomp opłacać Aspect=Imp|VerbForm=Inf|Voice=Act
# pracować INF VERB xcomp pracować Aspect=Imp|VerbForm=Inf|Voice=Act
# . INTERP PUNCT punct . PunctType=Peri
# Do PREP ADP case do AdpType=Prep
# tego SUBST PRON obl:arg to Case=Gen|Gender=Neut|Number=Sing|PronType=Dem
# te ADJ DET det ten Case=Nom|Gender=Neut|Number=Plur|PronType=Dem
# rozwiązania SUBST NOUN obj rozwiązanie Case=Nom|Gender=Neut|Number=Plur
# prowadzą FIN VERB ROOT prowadzić Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# . INTERP PUNCT punct . PunctType=Peri
# Nie QUB PART advmod:neg nie Polarity=Neg
# ma FIN VERB ROOT mieć Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# rozwiązań SUBST NOUN nsubj rozwiązanie Case=Gen|Gender=Neut|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# które ADJ DET nsubj który Case=Acc|Gender=Neut|Number=Sing|PronType=Rel
# zapowiadaliście FIN VERB acl:relcl zapowiadaliście Animacy=Hum|Aspect=Imp,Perf|Clitic=Yes|Gender=Masc|Mood=Ind|Number=Plur|Person=2|Tense=Past|Variant=Short|VerbForm=Fin|Voice=Act
# , INTERP PUNCT punct , PunctType=Comm
# jeśli COMP SCONJ mark jeśli
# chodzi FIN VERB advcl chodzić Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# o PREP ADP case o AdpType=Prep
# korektę SUBST NOUN obl:arg korekta Case=Acc|Gender=Fem|Number=Sing
# Nowego ADJ ADJ amod:flat Nowy Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
# Ładu SUBST NOUN nmod:arg Ładu Case=Gen|Gender=Fem|Number=Plur
# . INTERP PUNCT punct . PunctType=Peri
# Nie QUB PART advmod:neg nie Polarity=Neg
# ma FIN VERB ROOT mieć Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# w PREP ADP case w AdpType=Prep|Variant=Short
# dalszym ADJ ADJ amod daleki Animacy=Inan|Case=Loc|Degree=Cmp|Gender=Masc|Number=Sing
# ciągu SUBST NOUN obl ciąg Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# ulgi SUBST NOUN nmod:arg ulga Case=Gen|Gender=Fem|Number=Sing
# dla PREP ADP case dla AdpType=Prep
# klasy SUBST NOUN nmod klasa Case=Gen|Gender=Fem|Number=Sing
# średniej ADJ ADJ amod średni Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# dla PREP ADP case dla AdpType=Prep
# zleceniobiorców SUBST NOUN nmod zleceniobiorca Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# dla PREP ADP case dla AdpType=Prep
# świadczeń SUBST NOUN nmod świadczenie Case=Gen|Gender=Neut|Number=Plur
# emerytalnych ADJ ADJ amod emerytalny Case=Gen|Degree=Pos|Gender=Neut|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# rentowych ADJ ADJ conj rentowy Case=Gen|Degree=Pos|Gender=Fem|Number=Plur
# . INTERP PUNCT punct . PunctType=Peri
# Nie QUB PART advmod:neg nie Polarity=Neg
# ma FIN VERB ROOT mieć Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# żadnej ADJ DET det żaden Case=Gen|Gender=Fem|Number=Sing|PronType=Neg
# propozycji SUBST NOUN iobj propozycja Case=Gen|Gender=Fem|Number=Sing
# co COMP SCONJ mark co
# do PREP ADP case do AdpType=Prep
# rozliczania GER NOUN obl rozliczać Aspect=Imp|Case=Gen|Gender=Neut|Number=Sing|Polarity=Pos|VerbForm=Vnoun
# rodziców SUBST NOUN obj rodzic Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur
# samotnie ADV ADV advmod samotnie Degree=Pos
# wychowujących PACT ADJ acl wychowuć Animacy=Hum|Aspect=Imp|Case=Gen|Gender=Masc|Number=Plur|Polarity=Pos|VerbForm=Part|Voice=Act
# dzieci SUBST NOUN obj dziecko Case=Acc|Gender=Neut|NumType=Sets|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# a CONJ CCONJ cc a
# taką ADJ DET det taki Case=Acc|Gender=Fem|Number=Sing|PronType=Dem
# deklarację SUBST NOUN obj deklaracja Case=Acc|Gender=Fem|Number=Sing
# też QUB PART advmod:emph też
# słyszeliśmy FIN VERB conj słyszeć być Animacy=Hum|Aspect=Imp|Clitic=Yes|Gender=Masc|Mood=Ind|Number=Plur|Person=1|Tense=Past|Variant=Short|VerbForm=Fin|Voice=Act
# . INTERP PUNCT punct . PunctType=Peri
# Nie QUB PART advmod:neg nie Polarity=Neg
# ma FIN VERB ROOT mieć Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# rekompensaty SUBST NOUN iobj rekompensata Case=Gen|Gender=Fem|Number=Sing
# dla PREP ADP case dla AdpType=Prep
# organizacji SUBST NOUN nmod organizacja Case=Gen|Gender=Fem|Number=Plur
# pozarządowych ADJ ADJ amod pozarządowy Case=Gen|Degree=Pos|Gender=Fem|Number=Plur
# . INTERP PUNCT punct . PunctType=Peri
# Nie QUB PART advmod:neg nie Polarity=Neg
# ma FIN VERB ROOT mieć Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# propozycji SUBST NOUN nsubj propozycja Case=Gen|Gender=Fem|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# o PREP ADP case o AdpType=Prep
# której ADJ DET obl:arg który Case=Loc|Gender=Fem|Number=Sing|PronType=Rel
# mówił PRAET VERB acl:relcl mówić Animacy=Hum|Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# też QUB PART advmod:emph też
# premier SUBST NOUN nsubj premier Animacy=Hum|Case=Nom|Gender=Masc|Number=Sing
# : INTERP PUNCT punct : PunctType=Colo
# złotówka SUBST NOUN parataxis:obj złotówka Case=Nom|Gender=Fem|Number=Sing
# za PREP ADP case za AdpType=Prep
# złotówkę SUBST NOUN nmod złotówka Case=Acc|Gender=Fem|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# I CONJ CCONJ cc i
# nie QUB PART advmod:neg nie Polarity=Neg
# odnosicie FIN VERB ROOT odnosić Aspect=Imp|Mood=Imp|Number=Plur|Person=2|VerbForm=Fin|Voice=Act
# się QUB PRON expl:pv się PronType=Prs|Reflex=Yes
# w PREP ADP advmod w AdpType=Prep|Variant=Short
# ogóle SUBST NOUN fixed ogół Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
# do PREP ADP case do AdpType=Prep
# konsekwencji SUBST NOUN obl konsekwencja Case=Gen|Gender=Fem|Number=Sing
# Nowego ADJ ADJ amod:flat Nowy Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
# Ładu SUBST NOUN nmod:arg Ładu Case=Gen|Gender=Fem|Number=Plur
# ( INTERP PUNCT punct ( PunctSide=Ini|PunctType=Brck
# Dzwonek SUBST NOUN nmod dzwonek Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# ) INTERP PUNCT punct ) PunctSide=Fin|PunctType=Brck
# w PREP ADP case w AdpType=Prep|Variant=Short
# działalności SUBST NOUN obl działalność Case=Loc|Gender=Fem|Number=Sing
# gospodarczej ADJ ADJ amod gospodarczy Case=Loc|Degree=Pos|Gender=Fem|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# a CONJ CCONJ cc a
# one PPRON3 PRON nsubj on Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur|Person=3|PrepCase=Npr|PronType=Prs|Variant=Long
# są FIN AUX cop być Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act
# tu ADV ADV advmod tu PronType=Dem
# dramatyczne ADJ ADJ conj dramatyczny Case=Nom|Degree=Pos|Gender=Fem|Number=Plur
# , INTERP PUNCT punct , PunctType=Comm
# dramatyczne ADJ ADJ conj dramatyczny Case=Nom|Degree=Pos|Gender=Neut|Number=Sing
# . INTERP PUNCT punct . PunctType=Peri
# Czas SUBST NOUN ROOT czas Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# albo CONJ CCONJ cc albo
# dokonać INF VERB conj dokonać Aspect=Perf|VerbForm=Inf|Voice=Act
# głębokiej ADJ ADJ amod głęboki Case=Gen|Degree=Pos|Gender=Fem|Number=Sing
# korekty SUBST NOUN obj korekta Case=Gen|Gender=Fem|Number=Sing
# , INTERP PUNCT punct , PunctType=Comm
# a CONJ CCONJ cc a
# najlepiej ADV ADV advmod dobrze Degree=Sup
# posłuchać INF VERB conj posłuchać Aspect=Perf|VerbForm=Inf|Voice=Act
# tego SUBST PRON obj to Case=Gen|Gender=Neut|Number=Sing|PronType=Dem
# , INTERP PUNCT punct , PunctType=Comm
# co SUBST PRON obj co Case=Acc|Gender=Neut|Number=Sing|PronType=Rel
# mówiliśmy PRAET VERB acl:relcl mówić być Animacy=Hum|Aspect=Imp|Clitic=Yes|Gender=Masc|Mood=Ind|Number=Plur|Person=1|Tense=Past|Variant=Short|VerbForm=Fin|Voice=Act
# od PREP ADP case od AdpType=Prep|Variant=Short
# samego ADJ ADJ amod sam Animacy=Inan|Case=Gen|Degree=Pos|Gender=Masc|Number=Sing
# początku SUBST NOUN obl początek Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# i CONJ CCONJ cc i
# tę ADJ DET det ten Case=Acc|Gender=Fem|Number=Sing|PronType=Dem
# część SUBST NOUN obj część Case=Acc|Gender=Fem|Number=Sing
# dotyczącą PACT ADJ acl dotyczyć Aspect=Imp|Case=Acc|Gender=Fem|Number=Sing|Polarity=Pos|VerbForm=Part|Voice=Act
# przedsiębiorców SUBST NOUN iobj przedsiębiorca Animacy=Hum|Case=Gen|Gender=Masc|Number=Plur
# po PREP ADP case po AdpType=Prep
# prostu ADJP ADJ obl prosty PrepCase=Pre
# zawiesić INF VERB conj zawiesić Aspect=Perf|VerbForm=Inf|Voice=Act
# . INTERP PUNCT punct . PunctType=Peri
# Dziękuję FIN VERB ROOT dziękować Aspect=Imp|Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin|Voice=Act
# bardzo SUBST ADV advmod bardzo Degree=Pos
# . INTERP PUNCT punct . PunctType=Peri

# %% [markdown]
# Parsowanie zależnościowe opisuje związki między wyrazami w zdaniu. Żeby obejrzeć graf zależności można użyć załączonej biblioteki `displacy`. Zaimportuj moduł `displacy` z biblioteki `spacy` i użyj jego funkcji `render` żeby narysować obraz.
#
# Pierwszy arguemnt metody `render` jest objekt jaki chcemy narysować - w naszym przypadku jest to powyższe zdanie. Argument `style` ustawiamy na rodzaj wykresu jaki chcemy narysować - w naszym wypadku ma to być `'dep'`. Dodatkowo musimy ustawić argument `jupyter` na `True` żeby się wykres wyświetlił w środowisku notebookowym:

# %%
from spacy import displacy 
doc = sejm
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pl" id="14199d136c654e34bcbe6904e758b3c5-0" class="displacy" width="105925" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Szanowny</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Panie</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Marszałku!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Wysoka</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Izbo!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Ustawa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">zapowiadana</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">jako</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">naprawa,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">chciałoby</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">się</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">rzec,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">głęboka</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">korekta</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Nowego</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Ładu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">podatkowego</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">poza</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">rekompensatą</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">strat,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">jeśli</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">chodzi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">o</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">zakłady</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">pracy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">chronionej</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">i</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">zakłady</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">aktywności</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">zawodowej,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">to</tspan>
#     <

# %%
zdanie2 = nlp(zdanie)
displacy.render(zdanie2, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pl" id="a9ba33700de44db487648b8212684dcf-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">To</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">jest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">opinia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Biura</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Legislacyjnego</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Sejmu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba33700de44db487648b8212684dcf-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba33700de44db487648b8212684dcf-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba33700de44db487648b8212684dcf-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba33700de44db487648b8212684dcf-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba33700de44db487648b8212684dcf-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba33700de44db487648b8212684dcf-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba33700de44db487648b8212684dcf-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba33700de44db487648b8212684dcf-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod:flat</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a9ba33700de44db487648b8212684dcf-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a9ba33700de44db487648b8212684dcf-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod:flat</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## NER
#
# Kolejnym ciekawym aspektem analizy jest rozpoznawanie encji - tzw. Named Entity Recognition. Dla całego przeiteruj atrybut `ents` i wypisz odpowiedznio `text` oraz `label_`:

# %%
doc = nlp(text_sample)
for i in range(len(doc)):
  ent = doc.ents[i]
  print(ent.text, ent.label_)
# Out:
# Wysoka Izbo orgName
# 7 stycznia 2022 r. date
# Orwella persName
# 2022 r. date
# 2021 r. date
# 2022 r. date
# 2021 r. date
# 2021 r. date
# 2022 r. date
# grudniu 2022 r. date
# polskich placeName
# Biuro Legislacyjne orgName
# Biura Legislacyjnego Sejmu orgName
# komisji finansów dowiedliście orgName
# ZUS orgName
# Polsce placeName
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-3f7e1d57ab18> in <module>()
#       1 doc = nlp(text_sample)
#       2 for i in range(len(doc)):
# ----> 3   ent = doc.ents[i]
#       4   print(ent.text, ent.label_)
#
# IndexError: tuple index out of range

# %% [markdown]
# Displacy też wspiera podświetlanie NER. Dla powyższego zdania (tego samego którego użyliśmy do wykresu parsowania zależnościowego) narysuj wykres o stylu `'ent'`. Jeśli w twoim zdaniu nie ma żadnych nazw, to wybierz jakieś inne zdanie:

# %% [markdown]
# ## word2vec
#
# Kolejną ciekawą cechą to są wektory rzeczywiste opisujące poszczególne wyrazy.
#
# Wypis następujące cechy dla poszczególnych tokenów wybranego zdania:
# * `has_vector`
# * `is_oov`
# * `vector_norm`

# %%
doc = nlp(zdanie)
for i in range(len(doc)):
  token = doc[i]
  print(token.has_vector, token.is_oov, token.vector_norm)
# Out:
# True False 87.82863
# True False 47.48863
# True False 33.786537
# True False 43.61287
# True False 23.176064
# True False 38.670162

# %% [markdown]
# No i oczywiście jest sam `vector`, ale jest on trochę długi żeby go wypisywać metodą `print` dla każdego wyrazu. Zamiast tego narysujemy wykres z położeniami wektorów w przestzeni.
#
# Najpierw przepisz wszystkie wektory dla całego tekstu w słowniku mapującym tekstu wyrazu na jego wektor:

# %% [markdown]
# Niestety nie możemy rysować wszystkie 300 wynmiarów wektora, więc zastosujemy popularną metodę do rzutowania wszystkich wymiarów do 2. Zaimportuj model `TSNE` z modułu `sklearn.manifold` i skonstruuj jego objekt podając w metodzie inicującej argument `n_components` równy 2. Potem zastosuj metodę `fit_transform` nowego objektu na wszystkich wektorach (na `values()` słownika wyżej) i zrób nowy słownik z nowo uzyskanymi wekotrami 2-wymiarowymi:

# %%
 from sklearn.manifold import TSNE

# %% [markdown]
# Żeby zacząć rysować w środowisku notebookowym wystarczy uruchomić polecenie magiczne `%pylab inline`. Zaimportuje to automatycznie numpy, matplotlib i ustawi odpowiednio rysowanie wykresów:

# %% [markdown]
# Teraz stwórz nowy wykres poleceniem `figure` i ustaw w nim atrybut `figsize` na parę `(15,15)`. W następnej linii uruchom metodę `scatter` i podaj w niej kolejno pierwszą i drugą kolumnę wszystkich wektorów z tablicy wektorów 2D jaką stworzyliśmy wyżej:

# %% [markdown]
# Możesz dodatkowo użyć metody `gca()` żeby pobrać objekt `Axes` który udostępnia metodę `text`. Metoda ta bierze 3 argumenty: x, y i string. Możesz użyć tej metody żeby wpisać odpowiednie wyrazy w odpowiednich miejscach na wykresie iterując po kolei słownik wektorów 2D.
#
# Ponieważ wykres jest z duży i nie widać wszystkich wyrazów razem, można użyć metod `xlim` i `ylim` żeby ograniczyć zakres tego co się wyświetla na ekranie. Niestety metody te nie mają wpływu na metodę `text`, więc w jej przypadku musisz samemu dokonać filtracji poleceniem `if`:

# %% [markdown]
# ### Praca domowa 1
#
# Narysuj wykres TSNE reprezentacji wektorowej jakiegoś dłuższego tekstu - powieści, artykułu zbioru poezji, ...

# %% [markdown]
# ## Dalsze rozważania na temat word2vec
#
# Model word2vec opisany wyżej może być użyty do rozwiązywania wielu zadań takich jak klasyfikacja, clustering, czy liczenie podobieństwa. Jest tez ciekawe zastosowanie polegające na wyszukiwaniu (generowaniu?) wyrazów. Do tego celu nie możemy jednak użyć biblioteki spacy. Ściągnijmy najpierw model word2vec wytrenowany na polskich tekstach z tego adresu:
#
# https://github.com/sdadas/polish-nlp-resources/releases/download/v1.0/word2vec.zip
#
# Ściągnij i rozpakuj powyższy plik:

# %% [markdown]
# Zaimportuj klasę `KeyedVectors` z biblioteki `gensim.models` i użyj metody `load` żeby wczytać plik `*.bin` rozpakowany wyżej:

# %% [markdown]
# Wczytany model umożliwia wyszukanie wyrazów podobnych do podanego metodą `similar_by_word`. Użyj tej metody do wyszukania wyrazu `tata`:

# %% [markdown]
# Model word2vec jest często używany do przedstawiania operacji arytmetycznych jakie można wykonywać na tych wektorach. Na przykład, odejmując "mężczyzna" od "tata" i dodając do wyniku "kobieta" powinniśmy otrzymać "mama".
#
# Do tego można użyć metody `most_similar` podając w argumencie `positive` listę `['kobieta','tata']` a w argumencie `negative` listę `['mężczyzna']`:

# %% [markdown]
# ### Praca domowa 2
#
# Wymyśl więcej przykłądów jak ten powyżej. Niektóre (większość) średnio działają (zależy to od rozmiaru i jakości modelu), ale niektóre mogą być ciekawe.

# %% [markdown]
# ## Modelowanie języka
#
# W tym zadaniu wytrenujemy prosty statystyczny model języka i sprawdzimy jego budowę i możliwości zastosowania.
#
# Do budowania modelu użyjemy pakietu SRILM. Jak zwykle, nie jest on jedynym narzędziem do tego zastosowania, ale jest jednym z najstarszych i najbardziej cytowanych:

# %%
# !wget -N http://users.pja.edu.pl/~danijel/zum/srilm-bin.tar.xz
# !tar xf srilm-bin.tar.xz bin/i686-m64/ngram bin/i686-m64/ngram-count
# %mv bin/i686-m64/* /usr/local/bin

# %% [markdown]
# Modele języka trenujemy na tzw. korpusach tekstów. Taki korpus to po prostu lista poprawnych zdań w wybranym języku - jedno zdanie na linię. Zróbmy taki miniaturowy przykładowy korpus zawierający 3 zdania:
# ```
# ala ma kota
# ala ma psa
# jan ma kota
# ```
#
# Zapisz te zdania do pliku `test.txt`:

# %% [markdown]
# Do utworzenia modelu języka użyjemy programu `ngram-count`. Program ten ma mnóstwo opcji, które można obejrzeć uruchamiając go z opcją `-help`. Nas będą interesować następujące ustawienia:
#
#  * `-text test.txt` - tym ustawimy plik źródłowy z korpusem
#  * `-order 3` - tym ustawimy to, że chcemy mieć model 3-gramowy
#  * `-wbdiscount` - użyjemy metodę wygładzania Witten-Bell
#  * `-lm out.arpa` - wynik zapiszemy do pliku `out.arpa`

# %% [markdown]
# Wypiszmy zawartość pliku `out.arpa`:

# %% [markdown]
# Format tego pliku jest dosyć prosty i czytelny. Składa się z nagłówka zaczynającego od tokenu `/data/` i zawierającego liczność poszczególnych n-gramów. Potem mamy kolejne sekcje, każda zawierająca listę poszczególnych n-gramów.
#
# Każdy n-gram jest opisany dwoma lub trzema polami oddzielonymi znakami `\t`:
# * prawdopodobieństwo danego n-gramu w skali logarytmicznej
# * opis samego n-gramu (tokeny/słowa oddzielone spacją)
# * opcjonalnie tzw. "*back-off weight*" też w skali log
#
# Back-off jest metodą do określenia prawdopodobieństwa n-gramów wyższego stopnia użwyając n-gramów niższego. Z tego powodu, najwyższe n-gramy (w naszym przypadku 3-gramy) nie mają policzonych wag back-off. Algorytm liczenia prawdopodonieństwa n-gramu jest następujący:
#
# * jeśli na liście jest dokładnie ten n-gram którego szukamy, bierzemy jego prawdopodobieństwo
# * jeśli go nie ma liście, bierzemy prawdopodobieństwo według wzoru:
#
# \begin{equation}
# P( word_N | word_{N-1}, word_{N-2}, ...., word_1 ) = \\
# P( word_N | word_{N-1}, word_{N-2}, ...., word_2 ) \cdot \text{backoff-weight}(  word_{N-1} | word_{N-2}, ...., word_1 )
# \end{equation}
#
# * jeśli brakuje prawdopodobieństwa n-gramu mniejszego stopnia, wtedy rekurencyjnie stosujemy ten sam wzór aż do unigramów (które wszystkie powinny być zdefiniowane)
# * jeśli brakuje wagi back-off, zakładmy wartość 1 (czyli 0 w skali logarytmicznej)
#
# Na przykład, prawdopodobieństwo n-gramu "*ala ma*" jest następujące:
#
# \begin{equation}
# P(ma|ala) = 10^{-0.1760913} = 0.6666666038148176
# \end{equation}
#
# A prawdopodobieństwo n-gramu "*jan ma psa*":
#
#
# \begin{equation}
# P(psa|jan,ma) = P(psa|ma)*bwt(ma|jan)=10^{(-0.69897+0)}=0.20000000199681048
# \end{equation}
#
# Użyjmy prostej biblioteki `arpa` żeby potwierdzić powyższe obliczenia. Dokumentacja do biblioteki jest [tutaj](https://pypi.org/project/arpa/). Bibliotekę trzeba najpierw zainstalować:

# %%
# !pip install arpa

# %% [markdown]
# Teaz zaimportuj całą bibliotekę `arpa` i użyj metody `loadf` żeby wczytać wyżej stworzony plik `out.arpa`. Metoda ta zwraca listę modeli, a nas oczywiście interesuje pierwszy (i jedyny) model.
#
# Po wczytaniu modelu można użyć wiele różnych metod. Nas interesuje metoda `p` która wylicza prawdopodobieństwo n-gramu. Dla powyższych przykładów, w pierwszym przypadku należy podać jako argument `'ala ma'` a w drugim `'jan ma psa'`:

# %% [markdown]
# Jeśli wszystko poszło dobrze, wartości powinny być takie same jak wyżej. Dla zainteresowanych modelami ARPA polecam poczytać (niedługi i nieskomplikowany) kod źródłowy tej biblioteki.
#
# Jedną z podstatowych miar jakości modelu języka to tzw. *perplexity*. Liczymy go stotując wytrenowany model języka na niezależnym zbiorze testowym. Zróbmy przykładowy zbiór zawierający jedno zdanie `ala ma osę` i zapiszmy w pliku `eval.txt`:

# %% [markdown]
# Do wyliczenia perplexity użyjemy programu `ngram` i użyjemy w nim opcję `-lm out.arpa` do wczytania pliku z modelem oraz `-ppl eval.txt` żeby policzyć perplexity na wybranym pliku:

# %% [markdown]
# Wyniki zawierają ilość zdań, słów i wyrazów spoza słownika (OOV - out-of-vocabulary). Zawiera też wyliczony logprob całego korpusu oraz perplexity wyczlione uwzględniając i nieuwzlgędniając sztucznie dodane tokeny `<s>` oraz `</s>`. Im mniejsza wartość PPL, tym model lepiej opisuje testowy zbiór tekstów.
#
# Program `ngram` ma mnóstwo zastosowań, głównie związanych z edycją i manipulacją wytrenowanego modelu języka. Ma też opcję `-gen <N>` do wygenerowania losowych zdań z konkretnego modelu języka:

# %% [markdown]
# ### Praca domowa 3
#
# Zrób model języka z większego tekstu, np ściągniętego stąd:
#
# http://users.pja.edu.pl/~danijel/zum/sejm-text.xz
#
# Sprawdź perplexity na przykładowym tekście i wygeneruj jakiś losowy tekst.
